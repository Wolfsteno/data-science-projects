# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Análisis

# %%
df = pd.read_csv("bmw_pricing_v3.csv")

print(df.info(), "\n")
print("NULOS:\n", df.isna().sum(), "\n")
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   marca                        3873 non-null   object
#  1   modelo                       4840 non-null   object
#  2   km                           4841 non-null   float64
#  3   potencia                     4842 non-null   float64
#  4   fecha_registro               2420 non-null   object
#  5   tipo_gasolina                4838 non-null   object
#  6   color                        4398 non-null   object
#  7   tipo_coche                   3383 non-null   object
#  8   volante_regulable            4839 non-null   object
#  9   aire_acondicionado           4357 non-null   object
#  10  camara_trasera               4841 non-null   object
#  11  asientos_traseros_plegables  1452 non-null   object
#  12  elevalunas_electrico         4841 non-null   object
#  13  bluetooth                    4115 non-null   object
#  14  gps                          4843 non-null   bool
#  15  alerta_lim_velocidad         4115 non-null   object
#  16  precio                       4837 non-null   float64
#  17  fecha_venta                  4842 non-null   object
# dtypes: bool(1), float64(3), object(14)
# memory usage: 648.1+ KB
# None
#
# NULOS:
#  marca                           970
# modelo                            3
# km                                2
# potencia                          1
# fecha_registro                 2423
# tipo_gasolina                     5
# color                           445
# tipo_coche                     1460
# volante_regulable                 4
# aire_acondicionado              486
# camara_trasera                    2
# asientos_traseros_plegables    3391
# elevalunas_electrico              2
# bluetooth                       728
# gps                               0
# alerta_lim_velocidad            728
# precio                            6
# fecha_venta                       1
# dtype: int64
#   marca modelo        km  potencia fecha_registro tipo_gasolina   color  \
# 0   NaN    118  140411.0     100.0     2012-02-01        diesel   black
# 1   BMW     M4   13929.0     317.0            NaN        petrol    grey
# 2   BMW    320  183297.0     120.0     2012-04-01        diesel   white
# 3   BMW    420  128035.0     135.0            NaN        diesel     red
# 4   BMW    425   97097.0     160.0            NaN        diesel  silver
#
#     tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 0          NaN              True               True          False
# 1  convertible              True               True          False
# 2          NaN             False              False          False
# 3  convertible              True               True          False
# 4          NaN              True               True          False
#
#   asientos_traseros_plegables elevalunas_electrico bluetooth   gps  \
# 0                         NaN                 True       NaN  True
# 1                         NaN                False      True  True
# 2                         NaN                 True     False  True
# 3                         NaN                 True      True  True
# 4                       False                False      True  True
#
#   alerta_lim_velocidad   precio fecha_venta
# 0                  NaN  11300.0  2018-01-01
# 1                 True  69700.0  2018-02-01
# 2                False  10200.0  2018-02-01
# 3                  NaN  25100.0  2018-02-01
# 4                 True  33400.0  2018-04-01

# %% [markdown]
# **Tras un análisis de los datos en equipo, hemos decidido eliminar estas dos columnas**
# - **Marca**: Ya que todos los valores son "BMW", por lo que no aporta ningun tipo de info interesante
# - **asientos_traseros_plegables**: Se decidio que no era necesaria para el análisis además de tener un 70% de nulos

# %%
del_cols = ["marca", "asientos_traseros_plegables"]

for col in del_cols:
    del df[col]

print(df.info(), "\n")
print("NULOS:\n", df.isna().sum(), "\n")
df.isna().sum().plot(kind="bar")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                4840 non-null   object
#  1   km                    4841 non-null   float64
#  2   potencia              4842 non-null   float64
#  3   fecha_registro        2420 non-null   object
#  4   tipo_gasolina         4838 non-null   object
#  5   color                 4398 non-null   object
#  6   tipo_coche            3383 non-null   object
#  7   volante_regulable     4839 non-null   object
#  8   aire_acondicionado    4357 non-null   object
#  9   camara_trasera        4841 non-null   object
#  10  elevalunas_electrico  4841 non-null   object
#  11  bluetooth             4115 non-null   object
#  12  gps                   4843 non-null   bool
#  13  alerta_lim_velocidad  4115 non-null   object
#  14  precio                4837 non-null   float64
#  15  fecha_venta           4842 non-null   object
# dtypes: bool(1), float64(3), object(12)
# memory usage: 572.4+ KB
# None
#
# NULOS:
#  modelo                     3
# km                         2
# potencia                   1
# fecha_registro          2423
# tipo_gasolina              5
# color                    445
# tipo_coche              1460
# volante_regulable          4
# aire_acondicionado       486
# camara_trasera             2
# elevalunas_electrico       2
# bluetooth                728
# gps                        0
# alerta_lim_velocidad     728
# precio                     6
# fecha_venta                1
# dtype: int64
# <Axes: >

# %% [markdown]
# Después de observar los datos, vimos que habían columnas con 6 o menos nulos, por lo que en estos casos decidimos eliminar las filas donde estaban esos nulos.

# %%
print("Antes de eliminar algunas filas con nulos")
print("Filas:", df.shape[0])

cols_pocos_nulos = ["modelo", "km", "potencia", "tipo_gasolina", "volante_regulable", "camara_trasera", "elevalunas_electrico", "precio", "fecha_venta"]
df.dropna(subset=cols_pocos_nulos, inplace=True)
df.reset_index(drop=True, inplace=True)

print("Después de eliminar algunas filas con nulos")
print("Filas:", df.shape[0])
# Out:
# Antes de eliminar algunas filas con nulos
# Filas: 4843
# Después de eliminar algunas filas con nulos
# Filas: 4817

# %% [markdown]
# Al aplicar el cambio podemos ver que tan solo se borraron 26 filas en total, ahora nos toca volver a análizar los datos y ver que hacemos con las columnas con muchos nulos

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4817 entries, 0 to 4816
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                4817 non-null   object
#  1   km                    4817 non-null   float64
#  2   potencia              4817 non-null   float64
#  3   fecha_registro        2408 non-null   object
#  4   tipo_gasolina         4817 non-null   object
#  5   color                 4375 non-null   object
#  6   tipo_coche            3368 non-null   object
#  7   volante_regulable     4817 non-null   object
#  8   aire_acondicionado    4335 non-null   object
#  9   camara_trasera        4817 non-null   object
#  10  elevalunas_electrico  4817 non-null   object
#  11  bluetooth             4092 non-null   object
#  12  gps                   4817 non-null   bool
#  13  alerta_lim_velocidad  4092 non-null   object
#  14  precio                4817 non-null   float64
#  15  fecha_venta           4817 non-null   object
# dtypes: bool(1), float64(3), object(12)
# memory usage: 569.3+ KB
# None
#   modelo        km  potencia fecha_registro tipo_gasolina   color  \
# 0    118  140411.0     100.0     2012-02-01        diesel   black
# 1     M4   13929.0     317.0            NaN        petrol    grey
# 2    320  183297.0     120.0     2012-04-01        diesel   white
# 3    420  128035.0     135.0            NaN        diesel     red
# 4    425   97097.0     160.0            NaN        diesel  silver
#
#     tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 0          NaN              True               True          False
# 1  convertible              True               True          False
# 2          NaN             False              False          False
# 3  convertible              True               True          False
# 4          NaN              True               True          False
#
#   elevalunas_electrico bluetooth   gps alerta_lim_velocidad   precio  \
# 0                 True       NaN  True                  NaN  11300.0
# 1                False      True  True                 True  69700.0
# 2                 True     False  True                False  10200.0
# 3                 True      True  True                  NaN  25100.0
# 4                False      True  True                 True  33400.0
#
#   fecha_venta
# 0  2018-01-01
# 1  2018-02-01
# 2  2018-02-01
# 3  2018-02-01
# 4  2018-04-01

# %% [markdown]
# Podemos darnos cuenta que varias columnas que deberían ser bool el dataframe las tomó como object y suponemos que es porque contienen nulos ("gps" no tiene nulos y tiene el Dtype de bool).
# También nos surge la duda de si las columnas float tienen bien sus valores o no, por lo que miramos sus rangos de valores.

# %%
df.describe()
# Out:
#                  km     potencia         precio
# count  4.817000e+03  4817.000000    4817.000000
# mean   1.409353e+05   128.984845   15841.831015
# std    6.024268e+04    39.004876    9223.064638
# min   -6.400000e+01     0.000000     100.000000
# 25%    1.027580e+05   100.000000   10900.000000
# 50%    1.409910e+05   120.000000   14200.000000
# 75%    1.752350e+05   135.000000   18600.000000
# max    1.000376e+06   423.000000  178500.000000

# %% [markdown]
# Vemos que la columna "km" tiene como mínimo -64km, al no tener sentido ese dato procederemos a eliminar las filas que contengan un km inferior 0.

# %%
df.drop(df[df["km"] < 0].index, inplace=True)
df.reset_index(drop=True, inplace=True)

df.describe()
# Out:
#                  km     potencia         precio
# count  4.816000e+03  4816.000000    4816.000000
# mean   1.409645e+05   128.963870   15829.547342
# std    6.021466e+04    38.981748    9184.530828
# min    4.760000e+02     0.000000     100.000000
# 25%    1.028315e+05   100.000000   10875.000000
# 50%    1.410270e+05   120.000000   14200.000000
# 75%    1.752392e+05   135.000000   18600.000000
# max    1.000376e+06   423.000000  178500.000000

# %% [markdown]
# Nos resulta raro que el mínimo de potencia sea 0 por lo que mostramos el dataframe ordenado por la potencia de manera ascendente.

# %%
df.sort_values("potencia",ascending=True)
# Out:
#      modelo        km  potencia fecha_registro  tipo_gasolina   color  \
# 3741     X1   81770.0       0.0     2014-10-01         diesel   white
# 1902     i3  152470.0      25.0            NaN  hybrid_petrol   black
# 1773     i3  152328.0      25.0            NaN  hybrid_petrol   black
# 2748    316  146951.0      66.0     1990-03-01         petrol   white
# 2367    318  170529.0      66.0            NaN         diesel  silver
# ...     ...       ...       ...            ...            ...     ...
# 3068     M3   39250.0     317.0     2015-11-01         petrol   black
# 70       M4   69410.0     317.0     2015-02-01         petrol   white
# 1        M4   13929.0     317.0            NaN         petrol    grey
# 3577     M5  150187.0     412.0            NaN         petrol   white
# 4122   X6 M    2970.0     423.0     2016-04-01         petrol     red
#
#        tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 3741          suv             False              False          False
# 1902    hatchback             False               True          False
# 1773          NaN             False               True          False
# 2748        sedan             False              False          False
# 2367    hatchback             False              False           True
# ...           ...               ...                ...            ...
# 3068        sedan              True               True          False
# 70            NaN              True               True          False
# 1     convertible              True               True          False
# 3577        sedan              True               True           True
# 4122          suv              True                NaN           True
#
#      elevalunas_electrico bluetooth    gps alerta_lim_velocidad   precio  \
# 3741                False     False  False                  NaN  11700.0
# 1902                False     False   True                 True  15500.0
# 1773                False     False   True                  NaN  20300.0
# 2748                False     False  False                False   1300.0
# 2367                False     False  False                False   1000.0
# ...                   ...       ...    ...                  ...      ...
# 3068                False      True   True                 True  52400.0
# 70                  False      True   True                 True  53600.0
# 1                   False      True   True                 True  69700.0
# 3577                 True      True   True                 True  41600.0
# 4122                False     False   True                 True  82400.0
#
#      fecha_venta
# 3741  2018-03-01
# 1902  2018-03-01
# 1773  2018-04-01
# 2748  2018-04-01
# 2367  2018-08-01
# ...          ...
# 3068  2018-05-01
# 70    2018-03-01
# 1     2018-02-01
# 3577  2018-09-01
# 4122  2018-04-01
#
# [4816 rows x 16 columns]

# %% [markdown]
# Podemos ver que el modelo "X1" es el unico coche con 0 de potencia, por lo que procedemos a mirar si tenemos más coches con modelo "X1" en nuestro dataframe, para ver su potencia.

# %%
df[df["modelo"] == "X1"]
# Out:
#      modelo        km  potencia fecha_registro tipo_gasolina   color  \
# 3719     X1   54157.0     105.0     2013-05-01        diesel   white
# 3720     X1  121114.0     135.0     2013-10-01        diesel    grey
# 3722     X1  167417.0     105.0            NaN        diesel   white
# 3723     X1   61354.0     105.0            NaN        diesel    blue
# 3724     X1   93308.0     135.0            NaN        diesel   white
# ...     ...       ...       ...            ...           ...     ...
# 4750     X1  137550.0     100.0            NaN        diesel  silver
# 4753     X1  140161.0     105.0            NaN        diesel   black
# 4755     X1  221585.0     105.0     2011-05-01        diesel  silver
# 4759     X1  120600.0      85.0     2013-03-01        diesel   black
# 4787     X1   73193.0     135.0     2013-03-01        diesel   black
#
#      tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 3719        suv              True               True          False
# 3720        suv             False              False          False
# 3722        suv             False              False          False
# 3723        NaN             False              False          False
# 3724        suv             False              False          False
# ...         ...               ...                ...            ...
# 4750        NaN              True               True          False
# 4753        suv             False              False          False
# 4755        suv              True                NaN          False
# 4759        NaN             False                NaN           True
# 4787        van              True               True          False
#
#      elevalunas_electrico bluetooth    gps alerta_lim_velocidad   precio  \
# 3719                False       NaN   True                  NaN  13100.0
# 3720                False     False  False                False  13100.0
# 3722                False     False  False                False   3600.0
# 3723                False     False  False                 True  16900.0
# 3724                False     False  False                 True  13900.0
# ...                   ...       ...    ...                  ...      ...
# 4750                 True     False   True                 True  13900.0
# 4753                False     False  False                  NaN  10700.0
# 4755                False       NaN   True                False   9400.0
# 4759                False     False  False                  NaN  11100.0
# 4787                False     False  False                 True  15600.0
#
#      fecha_venta
# 3719  2018-01-01
# 3720  2018-04-01
# 3722  2018-09-01
# 3723  2018-06-01
# 3724  2018-08-01
# ...          ...
# 4750  2018-09-01
# 4753  2018-09-01
# 4755  2018-09-01
# 4759  2018-09-01
# 4787  2018-04-01
#
# [274 rows x 16 columns]

# %%
print("Media:", df[df["modelo"] == "X1"]["potencia"].mean())
print("Moda:", df[df["modelo"] == "X1"]["potencia"].mode()[0])
df[df["modelo"] == "X1"]["potencia"].value_counts()
# Out:
# Media: 109.95255474452554
# Moda: 105.0
# potencia
# 105.0    91
# 100.0    54
# 85.0     36
# 135.0    33
# 120.0    31
# 130.0    13
# 160.0     9
# 150.0     3
# 110.0     2
# 0.0       1
# 137.0     1
# Name: count, dtype: int64

# %% [markdown]
# Podemos ver que la media de potencia para este modelo es 109.95, mientras que el valor que más aparece es 105, al tener un valor similar, decidimos cambiar el valor 0.0 por 105

# %%
df.loc[df["potencia"] == 0.0, "potencia"] = 105.0

df.describe()
# Out:
#                  km     potencia         precio
# count  4.816000e+03  4816.000000    4816.000000
# mean   1.409645e+05   128.985673   15829.547342
# std    6.021466e+04    38.938944    9184.530828
# min    4.760000e+02    25.000000     100.000000
# 25%    1.028315e+05   100.000000   10875.000000
# 50%    1.410270e+05   120.000000   14200.000000
# 75%    1.752392e+05   135.000000   18600.000000
# max    1.000376e+06   423.000000  178500.000000

# %% [markdown]
# Ahora que ya tenemos las columnas numericas con valores que nos hacen más sentido procedemos a volver a mirar que columnas nos quedan con nulos.

# %%
print(df.info(), "\n")
print("NULOS:\n", df.isna().sum(), "\n")
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4816 entries, 0 to 4815
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                4816 non-null   object
#  1   km                    4816 non-null   float64
#  2   potencia              4816 non-null   float64
#  3   fecha_registro        2408 non-null   object
#  4   tipo_gasolina         4816 non-null   object
#  5   color                 4374 non-null   object
#  6   tipo_coche            3367 non-null   object
#  7   volante_regulable     4816 non-null   object
#  8   aire_acondicionado    4334 non-null   object
#  9   camara_trasera        4816 non-null   object
#  10  elevalunas_electrico  4816 non-null   object
#  11  bluetooth             4091 non-null   object
#  12  gps                   4816 non-null   bool
#  13  alerta_lim_velocidad  4091 non-null   object
#  14  precio                4816 non-null   float64
#  15  fecha_venta           4816 non-null   object
# dtypes: bool(1), float64(3), object(12)
# memory usage: 569.2+ KB
# None
#
# NULOS:
#  modelo                     0
# km                         0
# potencia                   0
# fecha_registro          2408
# tipo_gasolina              0
# color                    442
# tipo_coche              1449
# volante_regulable          0
# aire_acondicionado       482
# camara_trasera             0
# elevalunas_electrico       0
# bluetooth                725
# gps                        0
# alerta_lim_velocidad     725
# precio                     0
# fecha_venta                0
# dtype: int64
#   modelo        km  potencia fecha_registro tipo_gasolina   color  \
# 0    118  140411.0     100.0     2012-02-01        diesel   black
# 1     M4   13929.0     317.0            NaN        petrol    grey
# 2    320  183297.0     120.0     2012-04-01        diesel   white
# 3    420  128035.0     135.0            NaN        diesel     red
# 4    425   97097.0     160.0            NaN        diesel  silver
#
#     tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 0          NaN              True               True          False
# 1  convertible              True               True          False
# 2          NaN             False              False          False
# 3  convertible              True               True          False
# 4          NaN              True               True          False
#
#   elevalunas_electrico bluetooth   gps alerta_lim_velocidad   precio  \
# 0                 True       NaN  True                  NaN  11300.0
# 1                False      True  True                 True  69700.0
# 2                 True     False  True                False  10200.0
# 3                 True      True  True                  NaN  25100.0
# 4                False      True  True                 True  33400.0
#
#   fecha_venta
# 0  2018-01-01
# 1  2018-02-01
# 2  2018-02-01
# 3  2018-02-01
# 4  2018-04-01

# %% [markdown]
# Aquí vemos las columnas y sus nulos:
# - color: 442
# - tipo_coche: 1449
# - aire_acondicionado: 482
# - bluetooth: 725
# - alerta_lim_velocidad: 725
# - fecha_registro: 2408

# %% [markdown]
# Para acabar con los nulos de la columna "color" rellenaremos los nulos con la moda de cada modelo, por ejemplo, si el modelo X1 tiene de moda el color verde pues los campos de color nulos con modelo X1 se rellenaran con verde y en caso de que todos los modelos X1 fueran nulos pues usaremos la moda de toda la columna.

# %%
df_check_null_color = df[["modelo", "color"]]
lista_modelos_sin_color = df_check_null_color[df_check_null_color["color"].isna()]["modelo"].value_counts().iloc[:].index.to_list()

for i in lista_modelos_sin_color:
    print(i, end=", ")
# Out:
# 320, 318, 520, X3, 116, X1, 316, X5, 118, 525, 530, 318 Gran Turismo, X4, 120, 420, 518, 535, 320 Gran Turismo, X6, 530 Gran Turismo, 420 Gran Coupé, 114, M550, 640, 730, X6 M, 520 Gran Turismo, 330, X5 M, 218 Active Tourer, 218, 135, 740, 325 Gran Turismo, 640 Gran Coupé, 335 Gran Turismo, 435 Gran Coupé, 325, 335, 225 Active Tourer,

# %%
for modelo in lista_modelos_sin_color:
    mask = df["modelo"] == str(modelo)
    moda = df["color"].mode()[0] if df.loc[mask, "color"].isna().all() else df.loc[mask, "color"].mode()[0]
    df.loc[mask, "color"] = df.loc[mask, "color"].fillna(moda)

print("NULOS:\n", df.isna().sum(), "\n")
# Out:
# NULOS:
#  modelo                     0
# km                         0
# potencia                   0
# fecha_registro          2408
# tipo_gasolina              0
# color                      0
# tipo_coche              1449
# volante_regulable          0
# aire_acondicionado       482
# camara_trasera             0
# elevalunas_electrico       0
# bluetooth                725
# gps                        0
# alerta_lim_velocidad     725
# precio                     0
# fecha_venta                0
# dtype: int64

# %% [markdown]
# Ahora solo nos quedan las siguientes columnas con nulos:
# - tipo_coche
# - aire_acondicionado
# - bluetooth
# - alerta_lim_velocidad
# - fecha_registro

# %% [markdown]
# Ahora aplicaremos una lógica parecida con las columnas tipo_coche, aire_acondicionado, bluetooth

# %%
df_check_null_tipo_coche = df[["modelo", "tipo_coche"]]
lista_modelos_sin_tipo_coche = df_check_null_tipo_coche[df_check_null_tipo_coche["tipo_coche"].isna()]["modelo"].value_counts().iloc[:].index.to_list()

for modelo in lista_modelos_sin_tipo_coche:
    mask = df["modelo"] == str(modelo)
    moda = df["tipo_coche"].mode()[0] if df.loc[mask, "tipo_coche"].isna().all() else df.loc[mask, "tipo_coche"].mode()[0]
    df.loc[mask, "tipo_coche"] = df.loc[mask, "tipo_coche"].fillna(moda)

print("NULOS:\n", df.isna().sum(), "\n")
# Out:
# NULOS:
#  modelo                     0
# km                         0
# potencia                   0
# fecha_registro          2408
# tipo_gasolina              0
# color                      0
# tipo_coche                 0
# volante_regulable          0
# aire_acondicionado       482
# camara_trasera             0
# elevalunas_electrico       0
# bluetooth                725
# gps                        0
# alerta_lim_velocidad     725
# precio                     0
# fecha_venta                0
# dtype: int64

# %% [markdown]
# Al ver que se nos hacía repetitivo usar el código y quedaba muy engorroso, decidimos hacer una función para aplicar estos cambios.

# %%
def fill_nulls(df, target: str):
    df_check_null_tipo_coche = df[["modelo", target]]
    lista_modelos_sin_tipo_coche = df_check_null_tipo_coche[df_check_null_tipo_coche[target].isna()]["modelo"].value_counts().iloc[:].index.to_list()

    for modelo in lista_modelos_sin_tipo_coche:
        mask = df["modelo"] == str(modelo)
        moda = df[target].mode()[0] if df.loc[mask, target].isna().all() else df.loc[mask, target].mode()[0]
        df.loc[mask, target] = df.loc[mask, target].fillna(moda)

    return df

# %%
print("Pre-función:")
print(df["aire_acondicionado"].value_counts(),"\n")
df = fill_nulls(df, "aire_acondicionado")
print("Post-función:")
print(df["aire_acondicionado"].value_counts(), "\n")

print("Pre-función:")
print(df["bluetooth"].value_counts(),"\n")
df = fill_nulls(df, "bluetooth")
print("Post-función:")
print(df["bluetooth"].value_counts(), "\n")
# Out:
# Pre-función:
# aire_acondicionado
# True     3448
# False     886
# Name: count, dtype: int64
#
# Post-función:
# aire_acondicionado
# True     3925
# False     891
# Name: count, dtype: int64
#
# Pre-función:
# bluetooth
# False    3100
# True      991
# Name: count, dtype: int64
#
# Post-función:
# bluetooth
# False    3795
# True     1021
# Name: count, dtype: int64
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)

# %% [markdown]
# Con estos prints podemos ver como evoluciona la cantidad de cada valor en las columnas antes y después de aplicar la función.

# %%
print("NULOS:\n", df.isna().sum(), "\n")
# Out:
# NULOS:
#  modelo                     0
# km                         0
# potencia                   0
# fecha_registro          2408
# tipo_gasolina              0
# color                      0
# tipo_coche                 0
# volante_regulable          0
# aire_acondicionado         0
# camara_trasera             0
# elevalunas_electrico       0
# bluetooth                  0
# gps                        0
# alerta_lim_velocidad     725
# precio                     0
# fecha_venta                0
# dtype: int64

# %% [markdown]
# Ahora solo nos quedan las siguientes columnas con nulos:
# - alerta_lim_velocidad
# - fecha_registro

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['potencia'], df['alerta_lim_velocidad'], color='blue', alpha=0.7)
plt.title('Relación entre potencia y alerta_lim_velocidad')
plt.xlabel('Potencia de Motor')
plt.ylabel('Alerta limite de velocidad')
plt.grid(True)
plt.show()

# %% [markdown]
# Podemos ver que la columna "potencia" tiene varios outliers, ahora veremos cuantos valores se salen de los rangos "normales" (que parece ser entre 50 y 350).

# %%
print("Pre-borrado:", df.shape[0])
df.drop(df[(df["potencia"] < 50.0) | (df["potencia"] > 350.0)].index, axis=0, inplace=True)
print("Post-borrado:", df.shape[0])
# Out:
# Pre-borrado: 4816
# Post-borrado: 4812

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['potencia'], df['alerta_lim_velocidad'], color='blue', alpha=0.7)
plt.title('Relación entre potencia y alerta_lim_velocidad')
plt.xlabel('Potencia de Motor')
plt.ylabel('Alerta limite de velocidad')
plt.grid(True)
plt.show()

# %% [markdown]
# Podemos ver que no hay mucha relación entre potencia y la alerta de limite de velocidad, ya que podemos ver que el False se concentra en potencias entre 50 y 200, y el True entre 100 y 250.

# %%
print(df[(df["potencia"] < 50.0) | (df["potencia"] > 250.0)].shape[0])

print(df.shape[0])
# Out:
# 44
# 4812

# %%
df_sup = df.copy()
df_sup.dropna(subset="alerta_lim_velocidad", inplace=True)
df_sup["alerta_lim_velocidad"] = df_sup["alerta_lim_velocidad"].astype("int64")
df_sup = pd.DataFrame(df_sup.groupby("modelo").agg({"alerta_lim_velocidad": "sum", "potencia": "mean"}))
df_sup.sort_values("potencia", ascending=False)
# Out:
#                    alerta_lim_velocidad    potencia
# modelo
# M4                                    2  317.000000
# M3                                    6  311.666667
# M550                                 11  280.000000
# 750                                   1  280.000000
# X5 M50                                3  280.000000
# ...                                 ...         ...
# 216 Active Tourer                     0   85.000000
# 216 Gran Tourer                       0   85.000000
# 316                                  39   84.837563
# 114                                   0   71.428571
# 214 Gran Tourer                       0   70.000000
#
# [74 rows x 2 columns]

# %% [markdown]
# No parece ser que este relacionado el modelo con la potencia, por lo que lo rellenare con la moda segun su modelo.

# %%
df = fill_nulls(df, "alerta_lim_velocidad")

df.isna().sum()
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/1361717979.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[mask, target] = df.loc[mask, target].fillna(moda)
# modelo                     0
# km                         0
# potencia                   0
# fecha_registro          2405
# tipo_gasolina              0
# color                      0
# tipo_coche                 0
# volante_regulable          0
# aire_acondicionado         0
# camara_trasera             0
# elevalunas_electrico       0
# bluetooth                  0
# gps                        0
# alerta_lim_velocidad       0
# precio                     0
# fecha_venta                0
# dtype: int64

# %%
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4812 entries, 0 to 4815
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                4812 non-null   object
#  1   km                    4812 non-null   float64
#  2   potencia              4812 non-null   float64
#  3   fecha_registro        2407 non-null   object
#  4   tipo_gasolina         4812 non-null   object
#  5   color                 4812 non-null   object
#  6   tipo_coche            4812 non-null   object
#  7   volante_regulable     4812 non-null   object
#  8   aire_acondicionado    4812 non-null   object
#  9   camara_trasera        4812 non-null   object
#  10  elevalunas_electrico  4812 non-null   object
#  11  bluetooth             4812 non-null   object
#  12  gps                   4812 non-null   bool
#  13  alerta_lim_velocidad  4812 non-null   object
#  14  precio                4812 non-null   float64
#  15  fecha_venta           4812 non-null   object
# dtypes: bool(1), float64(3), object(12)
# memory usage: 606.2+ KB
# None
#                  modelo        km  potencia fecha_registro tipo_gasolina  \
# 0                   118  140411.0     100.0     2012-02-01        diesel
# 1                    M4   13929.0     317.0            NaN        petrol
# 2                   320  183297.0     120.0     2012-04-01        diesel
# 3                   420  128035.0     135.0            NaN        diesel
# 4                   425   97097.0     160.0            NaN        diesel
# ...                 ...       ...       ...            ...           ...
# 4811    218 Gran Tourer   39743.0     110.0            NaN        diesel
# 4812  218 Active Tourer   49832.0     100.0     2015-06-01        diesel
# 4813    218 Gran Tourer   19633.0     110.0     2015-10-01        diesel
# 4814  218 Active Tourer   27920.0     110.0     2016-04-01        diesel
# 4815                525  195840.0     160.0            NaN        diesel
#
#        color   tipo_coche volante_regulable aire_acondicionado camara_trasera  \
# 0      black    hatchback              True               True          False
# 1       grey  convertible              True               True          False
# 2      white       estate             False              False          False
# 3        red  convertible              True               True          False
# 4     silver        coupe              True               True          False
# ...      ...          ...               ...                ...            ...
# 4811   black          van             False               True          False
# 4812    grey          van             False               True          False
# 4813    grey          van             False               True          False
# 4814   brown          van              True               True          False
# 4815    grey       estate              True               True          False
#
#      elevalunas_electrico bluetooth   gps alerta_lim_velocidad   precio  \
# 0                    True     False  True                False  11300.0
# 1                   False      True  True                 True  69700.0
# 2                    True     False  True                False  10200.0
# 3                    True      True  True                 True  25100.0
# 4                   False      True  True                 True  33400.0
# ...                   ...       ...   ...                  ...      ...
# 4811                False     False  True                False  14600.0
# 4812                False     False  True                 True  17500.0
# 4813                False     False  True                 True  17000.0
# 4814                False     False  True                 True  22700.0
# 4815                 True     False  True                 True  15500.0
#
#      fecha_venta
# 0     2018-01-01
# 1     2018-02-01
# 2     2018-02-01
# 3     2018-02-01
# 4     2018-04-01
# ...          ...
# 4811  2018-08-01
# 4812  2018-08-01
# 4813  2018-09-01
# 4814  2018-09-01
# 4815  2018-09-01
#
# [4812 rows x 16 columns]

# %% [markdown]
# Al ver que tenemos variables "bool" con dtype de "object", procedemos a cambiarlos a "bool" y las columnas que contienen fechas a un tipo date

# %%
cols_to_bool = ["volante_regulable", "aire_acondicionado", 
"camara_trasera",  "elevalunas_electrico", 
"bluetooth", "gps", "alerta_lim_velocidad"]

df = df.astype({"volante_regulable": "bool",
            "aire_acondicionado": "bool", 
            "camara_trasera": "bool",  
            "elevalunas_electrico": "bool",
            "bluetooth": "bool", 
            "gps": "bool", 
            "alerta_lim_velocidad": "bool"})

for col in ["fecha_registro", "fecha_venta"]:
    df[col] = pd.to_datetime(df[col])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4812 entries, 0 to 4815
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                4812 non-null   object
#  1   km                    4812 non-null   float64
#  2   potencia              4812 non-null   float64
#  3   fecha_registro        2407 non-null   datetime64[ns]
#  4   tipo_gasolina         4812 non-null   object
#  5   color                 4812 non-null   object
#  6   tipo_coche            4812 non-null   object
#  7   volante_regulable     4812 non-null   bool
#  8   aire_acondicionado    4812 non-null   bool
#  9   camara_trasera        4812 non-null   bool
#  10  elevalunas_electrico  4812 non-null   bool
#  11  bluetooth             4812 non-null   bool
#  12  gps                   4812 non-null   bool
#  13  alerta_lim_velocidad  4812 non-null   bool
#  14  precio                4812 non-null   float64
#  15  fecha_venta           4812 non-null   datetime64[ns]
# dtypes: bool(7), datetime64[ns](2), float64(3), object(4)
# memory usage: 408.8+ KB

# %% [markdown]
# La unica columna con nulos que nos queda es la de fecha_registro, como el equipo decidio mantener la columna para sacar el año y el mes, ya que parecia ser interesante, pues procederemos a ver como podriamos rellenar los nulos en esta columna.

# %%
df_sup = df.dropna()

print(df_sup.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2407 entries, 0 to 4814
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo                2407 non-null   object
#  1   km                    2407 non-null   float64
#  2   potencia              2407 non-null   float64
#  3   fecha_registro        2407 non-null   datetime64[ns]
#  4   tipo_gasolina         2407 non-null   object
#  5   color                 2407 non-null   object
#  6   tipo_coche            2407 non-null   object
#  7   volante_regulable     2407 non-null   bool
#  8   aire_acondicionado    2407 non-null   bool
#  9   camara_trasera        2407 non-null   bool
#  10  elevalunas_electrico  2407 non-null   bool
#  11  bluetooth             2407 non-null   bool
#  12  gps                   2407 non-null   bool
#  13  alerta_lim_velocidad  2407 non-null   bool
#  14  precio                2407 non-null   float64
#  15  fecha_venta           2407 non-null   datetime64[ns]
# dtypes: bool(7), datetime64[ns](2), float64(3), object(4)
# memory usage: 204.5+ KB
# None

# %%
df_sup["tiempo"] = df_sup["fecha_venta"] - df_sup["fecha_registro"]
df_sup
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_76268/137163859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sup["tiempo"] = df_sup["fecha_venta"] - df_sup["fecha_registro"]
#                  modelo        km  potencia fecha_registro tipo_gasolina  \
# 0                   118  140411.0     100.0     2012-02-01        diesel
# 2                   320  183297.0     120.0     2012-04-01        diesel
# 5                   335  152352.0     225.0     2011-05-01        petrol
# 7                   118  115560.0     105.0     2009-08-01        petrol
# 12                  420  132025.0     135.0     2014-03-01        diesel
# ...                 ...       ...       ...            ...           ...
# 4806  216 Active Tourer   14533.0      85.0     2015-04-01        diesel
# 4809  218 Active Tourer   81230.0     100.0     2015-07-01        diesel
# 4812  218 Active Tourer   49832.0     100.0     2015-06-01        diesel
# 4813    218 Gran Tourer   19633.0     110.0     2015-10-01        diesel
# 4814  218 Active Tourer   27920.0     110.0     2016-04-01        diesel
#
#       color   tipo_coche  volante_regulable  aire_acondicionado  \
# 0     black    hatchback               True                True
# 2     white       estate              False               False
# 5     black        coupe               True                True
# 7     white  convertible               True                True
# 12     blue        coupe               True                True
# ...     ...          ...                ...                 ...
# 4806   grey          van               True                True
# 4809  black          van              False                True
# 4812   grey          van              False                True
# 4813   grey          van              False                True
# 4814  brown          van               True                True
#
#       camara_trasera  elevalunas_electrico  bluetooth   gps  \
# 0              False                  True      False  True
# 2              False                  True      False  True
# 5              False                  True       True  True
# 7              False                 False       True  True
# 12             False                  True       True  True
# ...              ...                   ...        ...   ...
# 4806            True                 False      False  True
# 4809           False                 False      False  True
# 4812           False                 False      False  True
# 4813           False                 False      False  True
# 4814           False                 False      False  True
#
#       alerta_lim_velocidad   precio fecha_venta    tiempo
# 0                    False  11300.0  2018-01-01 2161 days
# 2                    False  10200.0  2018-02-01 2132 days
# 5                     True  17100.0  2018-02-01 2468 days
# 7                    False   6100.0  2018-02-01 3106 days
# 12                    True  21700.0  2018-03-01 1461 days
# ...                    ...      ...         ...       ...
# 4806                 False  16900.0  2018-07-01 1187 days
# 4809                 False  14200.0  2018-07-01 1096 days
# 4812                  True  17500.0  2018-08-01 1157 days
# 4813                  True  17000.0  2018-09-01 1066 days
# 4814                  True  22700.0  2018-09-01  883 days
#
# [2407 rows x 17 columns]

# %%
df_sup["tiempo"].max()
# Out:
# Timedelta('10258 days 00:00:00')

# %%
df_sup["tiempo"].min()
# Out:
# Timedelta('-2009 days +00:00:00')

# %%
df_sup.sort_values("tiempo", ascending=True)
# Out:
#      modelo        km  potencia fecha_registro tipo_gasolina  color  \
# 249     316  201102.0      85.0     2013-12-01        diesel  black
# 97      320  342768.0     135.0     2011-12-01        diesel  black
# 3911     X5     706.0     155.0     2017-07-01        diesel  black
# 136     330  122991.0     170.0     2017-11-01        diesel  green
# 3658    116    6777.0      85.0     2017-01-01        diesel  black
# ...     ...       ...       ...            ...           ...    ...
# 2450    525  230578.0      85.0     1997-07-01        diesel  black
# 3356    525  245302.0     105.0     1997-01-01        diesel  green
# 25      318  196092.0      85.0     1995-10-01        petrol  black
# 3038    318   98097.0      85.0     1994-01-01        petrol   blue
# 2748    316  146951.0      66.0     1990-03-01        petrol  white
#
#        tipo_coche  volante_regulable  aire_acondicionado  camara_trasera  \
# 249        estate               True                True           False
# 97         estate              False                True           False
# 3911          suv               True                True           False
# 136         coupe               True                True            True
# 3658   subcompact              False                True           False
# ...           ...                ...                 ...             ...
# 2450        sedan              False                True           False
# 3356       estate              False                True           False
# 25    convertible               True               False           False
# 3038        sedan               True               False           False
# 2748        sedan              False               False           False
#
#       elevalunas_electrico  bluetooth    gps  alerta_lim_velocidad   precio  \
# 249                  False      False   True                 False   8800.0
# 97                    True      False   True                  True   8200.0
# 3911                  True       True   True                  True  41600.0
# 136                   True      False   True                 False  11300.0
# 3658                 False      False   True                 False  11300.0
# ...                    ...        ...    ...                   ...      ...
# 2450                 False      False   True                  True    200.0
# 3356                 False      False   True                  True    900.0
# 25                   False      False  False                 False   1800.0
# 3038                 False      False   True                  True    400.0
# 2748                 False      False  False                 False   1300.0
#
#      fecha_venta     tiempo
# 249   2008-06-01 -2009 days
# 97    2010-04-01  -609 days
# 3911  2018-02-01   215 days
# 136   2018-08-01   273 days
# 3658  2018-03-01   424 days
# ...          ...        ...
# 2450  2018-08-01  7701 days
# 3356  2018-06-01  7821 days
# 25    2018-05-01  8248 days
# 3038  2018-04-01  8856 days
# 2748  2018-04-01 10258 days
#
# [2407 rows x 17 columns]

# %%
df.drop(df_sup[df_sup["tiempo"] < pd.Timedelta(0, unit="d")].index, inplace=True) #97 y 249
df
# Out:
#                  modelo        km  potencia fecha_registro tipo_gasolina  \
# 0                   118  140411.0     100.0     2012-02-01        diesel
# 1                    M4   13929.0     317.0            NaT        petrol
# 2                   320  183297.0     120.0     2012-04-01        diesel
# 3                   420  128035.0     135.0            NaT        diesel
# 4                   425   97097.0     160.0            NaT        diesel
# ...                 ...       ...       ...            ...           ...
# 4811    218 Gran Tourer   39743.0     110.0            NaT        diesel
# 4812  218 Active Tourer   49832.0     100.0     2015-06-01        diesel
# 4813    218 Gran Tourer   19633.0     110.0     2015-10-01        diesel
# 4814  218 Active Tourer   27920.0     110.0     2016-04-01        diesel
# 4815                525  195840.0     160.0            NaT        diesel
#
#        color   tipo_coche  volante_regulable  aire_acondicionado  \
# 0      black    hatchback               True                True
# 1       grey  convertible               True                True
# 2      white       estate              False               False
# 3        red  convertible               True                True
# 4     silver        coupe               True                True
# ...      ...          ...                ...                 ...
# 4811   black          van              False                True
# 4812    grey          van              False                True
# 4813    grey          van              False                True
# 4814   brown          van               True                True
# 4815    grey       estate               True                True
#
#       camara_trasera  elevalunas_electrico  bluetooth   gps  \
# 0              False                  True      False  True
# 1              False                 False       True  True
# 2              False                  True      False  True
# 3              False                  True       True  True
# 4              False                 False       True  True
# ...              ...                   ...        ...   ...
# 4811           False                 False      False  True
# 4812           False                 False      False  True
# 4813           False                 False      False  True
# 4814           False                 False      False  True
# 4815           False                  True      False  True
#
#       alerta_lim_velocidad   precio fecha_venta
# 0                    False  11300.0  2018-01-01
# 1                     True  69700.0  2018-02-01
# 2                    False  10200.0  2018-02-01
# 3                     True  25100.0  2018-02-01
# 4                     True  33400.0  2018-04-01
# ...                    ...      ...         ...
# 4811                 False  14600.0  2018-08-01
# 4812                  True  17500.0  2018-08-01
# 4813                  True  17000.0  2018-09-01
# 4814                  True  22700.0  2018-09-01
# 4815                  True  15500.0  2018-09-01
#
# [4810 rows x 16 columns]

# %%
#
#for modelo in lista_modelos:
#    print(modelo)
#    print("num:",len(df[df["modelo"] == modelo]))
#    print("num_na:", df[df["modelo"] == modelo]["fecha_registro"].isna().sum())
#

# %%
df = fill_nulls(df, "fecha_registro")

# %%
df["tiempo"] = df["fecha_venta"] - df["fecha_registro"]

df.isna().sum()
# Out:
# modelo                  0
# km                      0
# potencia                0
# fecha_registro          0
# tipo_gasolina           0
# color                   0
# tipo_coche              0
# volante_regulable       0
# aire_acondicionado      0
# camara_trasera          0
# elevalunas_electrico    0
# bluetooth               0
# gps                     0
# alerta_lim_velocidad    0
# precio                  0
# fecha_venta             0
# tiempo                  0
# dtype: int64

# %%
df[df["tiempo"] < pd.Timedelta(0, unit="d")]
# Out:
#     modelo        km  potencia fecha_registro tipo_gasolina  color  \
# 42     330  142483.0     180.0     2013-06-01        diesel   blue
# 175    320  181052.0     120.0     2012-10-01        diesel  black
#
#       tipo_coche  volante_regulable  aire_acondicionado  camara_trasera  \
# 42   convertible               True                True           False
# 175       estate              False                True           False
#
#      elevalunas_electrico  bluetooth   gps  alerta_lim_velocidad   precio  \
# 42                   True      False  True                  True  15800.0
# 175                 False      False  True                  True  11500.0
#
#     fecha_venta     tiempo
# 42   2007-08-01 -2131 days
# 175  2009-04-01 -1279 days

# %%
df.drop(df[df["tiempo"] < pd.Timedelta(0, unit="d")].index, inplace=True) #42, 175
df.reset_index(drop=True, inplace=True)
df
# Out:
#                  modelo        km  potencia fecha_registro tipo_gasolina  \
# 0                   118  140411.0     100.0     2012-02-01        diesel
# 1                    M4   13929.0     317.0     2015-02-01        petrol
# 2                   320  183297.0     120.0     2012-04-01        diesel
# 3                   420  128035.0     135.0     2014-04-01        diesel
# 4                   425   97097.0     160.0     2012-10-01        diesel
# ...                 ...       ...       ...            ...           ...
# 4803    218 Gran Tourer   39743.0     110.0     2015-10-01        diesel
# 4804  218 Active Tourer   49832.0     100.0     2015-06-01        diesel
# 4805    218 Gran Tourer   19633.0     110.0     2015-10-01        diesel
# 4806  218 Active Tourer   27920.0     110.0     2016-04-01        diesel
# 4807                525  195840.0     160.0     2012-10-01        diesel
#
#        color   tipo_coche  volante_regulable  aire_acondicionado  \
# 0      black    hatchback               True                True
# 1       grey  convertible               True                True
# 2      white       estate              False               False
# 3        red  convertible               True                True
# 4     silver        coupe               True                True
# ...      ...          ...                ...                 ...
# 4803   black          van              False                True
# 4804    grey          van              False                True
# 4805    grey          van              False                True
# 4806   brown          van               True                True
# 4807    grey       estate               True                True
#
#       camara_trasera  elevalunas_electrico  bluetooth   gps  \
# 0              False                  True      False  True
# 1              False                 False       True  True
# 2              False                  True      False  True
# 3              False                  True       True  True
# 4              False                 False       True  True
# ...              ...                   ...        ...   ...
# 4803           False                 False      False  True
# 4804           False                 False      False  True
# 4805           False                 False      False  True
# 4806           False                 False      False  True
# 4807           False                  True      False  True
#
#       alerta_lim_velocidad   precio fecha_venta    tiempo
# 0                    False  11300.0  2018-01-01 2161 days
# 1                     True  69700.0  2018-02-01 1096 days
# 2                    False  10200.0  2018-02-01 2132 days
# 3                     True  25100.0  2018-02-01 1402 days
# 4                     True  33400.0  2018-04-01 2008 days
# ...                    ...      ...         ...       ...
# 4803                 False  14600.0  2018-08-01 1035 days
# 4804                  True  17500.0  2018-08-01 1157 days
# 4805                  True  17000.0  2018-09-01 1066 days
# 4806                  True  22700.0  2018-09-01  883 days
# 4807                  True  15500.0  2018-09-01 2161 days
#
# [4808 rows x 17 columns]
