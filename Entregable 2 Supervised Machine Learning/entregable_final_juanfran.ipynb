# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pointbiserialr
import numpy as np

# %%
del_columns = []
pd.set_option('display.float_format', '{:.4f}'.format)

url = "https://www.dropbox.com/scl/fi/uvv7j1bragzqkz9zwyvj0/sample_mmp.csv?rlkey=i0mlaxzq6e3blblfu9mhrdpsm&e=1&dl=1"
df = pd.read_csv(url)

df
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_41132/2261725290.py:5: DtypeWarning: Columns (29,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#         Unnamed: 0                 MachineIdentifier   ProductName  \
# 0          8427007  f1cd864e97bae82bdf96523e1a539121  win8defender
# 1          8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender
# 2          2731904  4e628391e7cc7c482fb3286f486dbd25  win8defender
# 3          1359513  270a2e9d028144a4df12a9e3da79fba5  win8defender
# 4           236059  06ca8fa8d32c2abdc5b3577d676b3269  win8defender
# ...            ...                               ...           ...
# 499995     5826339  a739cacc292f3f1e745827c1ca6c6ada  win8defender
# 499996     5740034  a4c232d528d98343e8f1b73650da7b82  win8defender
# 499997     8819786  fd16cd542d660848d272e4552bcccb1e  win8defender
# 499998     8713685  fa0841f8f6147de7c3d287e05270ed42  win8defender
# 499999     4295573  7b45dc3537e17f16305c5983ca0a1cb9  win8defender
#
#        EngineVersion        AppVersion  AvSigVersion  IsBeta  \
# 0        1.1.15100.1   4.18.1807.18075  1.273.1234.0       0
# 1        1.1.15100.1   4.18.1807.18075  1.273.1282.0       0
# 2        1.1.15100.1    4.9.10586.1106   1.273.781.0       0
# 3        1.1.15200.1   4.18.1807.18075  1.275.1639.0       0
# 4        1.1.15200.1   4.18.1807.18075   1.275.511.0       0
# ...              ...               ...           ...     ...
# 499995   1.1.15200.1   4.18.1807.18075  1.275.1090.0       0
# 499996   1.1.15100.1   4.18.1807.18075  1.273.1620.0       0
# 499997   1.1.15300.5    4.13.17134.112  1.275.1343.0       0
# 499998   1.1.15100.1  4.14.17639.18041   1.273.483.0       0
# 499999   1.1.15100.1   4.18.1807.18075  1.273.1644.0       0
#
#         RtpStateBitfield  IsSxsPassiveMode  DefaultBrowsersIdentifier  ...  \
# 0                 7.0000                 0                        NaN  ...
# 1                 7.0000                 0                        NaN  ...
# 2                 7.0000                 0                        NaN  ...
# 3                 7.0000                 0                        NaN  ...
# 4                 7.0000                 0                        NaN  ...
# ...                  ...               ...                        ...  ...
# 499995            7.0000                 0                        NaN  ...
# 499996            7.0000                 0                        NaN  ...
# 499997            7.0000                 0                        NaN  ...
# 499998            7.0000                 0                        NaN  ...
# 499999            7.0000                 0                        NaN  ...
#
#         Census_FirmwareVersionIdentifier  Census_IsSecureBootEnabled  \
# 0                             19951.0000                           0
# 1                             48753.0000                           0
# 2                             33111.0000                           1
# 3                             48473.0000                           1
# 4                              4343.0000                           1
# ...                                  ...                         ...
# 499995                        33088.0000                           1
# 499996                               NaN                           0
# 499997                        41727.0000                           0
# 499998                        11947.0000                           0
# 499999                        12103.0000                           0
#
#         Census_IsWIMBootEnabled  Census_IsVirtualDevice  \
# 0                           NaN                  0.0000
# 1                        0.0000                  0.0000
# 2                        0.0000                  0.0000
# 3                           NaN                  0.0000
# 4                           NaN                  0.0000
# ...                         ...                     ...
# 499995                   0.0000                  0.0000
# 499996                      NaN                  0.0000
# 499997                      NaN                  0.0000
# 499998                      NaN                  0.0000
# 499999                      NaN                  0.0000
#
#         Census_IsTouchEnabled  Census_IsPenCapable  \
# 0                           0                    0
# 1                           0                    0
# 2                           1                    1
# 3                           0                    0
# 4                           1                    0
# ...                       ...                  ...
# 499995                      1                    0
# 499996                      0                    0
# 499997                      0                    0
# 499998                      0                    0
# 499999                      0                    0
#
#         Census_IsAlwaysOnAlwaysConnectedCapable  Wdft_IsGamer  \
# 0                                        0.0000        0.0000
# 1                                        0.0000        1.0000
# 2                                        0.0000        0.0000
# 3                                        0.0000        0.0000
# 4                                        0.0000        1.0000
# ...                                         ...           ...
# 499995                                   0.0000        1.0000
# 499996                                   0.0000        0.0000
# 499997                                   0.0000        0.0000
# 499998                                   0.0000        0.0000
# 499999                                   0.0000        1.0000
#
#         Wdft_RegionIdentifier HasDetections
# 0                     11.0000             1
# 1                      3.0000             0
# 2                     15.0000             0
# 3                     15.0000             1
# 4                     13.0000             1
# ...                       ...           ...
# 499995                10.0000             0
# 499996                15.0000             0
# 499997                 8.0000             0
# 499998                 1.0000             0
# 499999                 4.0000             1
#
# [500000 rows x 84 columns]

# %%
fran_columns = list(df.columns[0:21])
ignacio_columns = list(df.columns[21:42])
marc_columns = list(df.columns[42:63])
alvaro_columns = list(df.columns[63:85])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 84 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Unnamed: 0                                         500000 non-null  int64
#  1   MachineIdentifier                                  500000 non-null  object
#  2   ProductName                                        500000 non-null  object
#  3   EngineVersion                                      500000 non-null  object
#  4   AppVersion                                         500000 non-null  object
#  5   AvSigVersion                                       500000 non-null  object
#  6   IsBeta                                             500000 non-null  int64
#  7   RtpStateBitfield                                   498168 non-null  float64
#  8   IsSxsPassiveMode                                   500000 non-null  int64
#  9   DefaultBrowsersIdentifier                          24061 non-null   float64
#  10  AVProductStatesIdentifier                          498062 non-null  float64
#  11  AVProductsInstalled                                498062 non-null  float64
#  12  AVProductsEnabled                                  498062 non-null  float64
#  13  HasTpm                                             500000 non-null  int64
#  14  CountryIdentifier                                  500000 non-null  int64
#  15  CityIdentifier                                     481760 non-null  float64
#  16  OrganizationIdentifier                             345437 non-null  float64
#  17  GeoNameIdentifier                                  499984 non-null  float64
#  18  LocaleEnglishNameIdentifier                        500000 non-null  int64
#  19  Platform                                           500000 non-null  object
#  20  Processor                                          500000 non-null  object
#  21  OsVer                                              500000 non-null  object
#  22  OsBuild                                            500000 non-null  int64
#  23  OsSuite                                            500000 non-null  int64
#  24  OsPlatformSubRelease                               500000 non-null  object
#  25  OsBuildLab                                         499999 non-null  object
#  26  SkuEdition                                         500000 non-null  object
#  27  IsProtected                                        498074 non-null  float64
#  28  AutoSampleOptIn                                    500000 non-null  int64
#  29  PuaMode                                            126 non-null     object
#  30  SMode                                              470152 non-null  float64
#  31  IeVerIdentifier                                    496791 non-null  float64
#  32  SmartScreen                                        321404 non-null  object
#  33  Firewall                                           494838 non-null  float64
#  34  UacLuaenable                                       499377 non-null  float64
#  35  Census_MDC2FormFactor                              500000 non-null  object
#  36  Census_DeviceFamily                                500000 non-null  object
#  37  Census_OEMNameIdentifier                           494619 non-null  float64
#  38  Census_OEMModelIdentifier                          494236 non-null  float64
#  39  Census_ProcessorCoreCount                          497653 non-null  float64
#  40  Census_ProcessorManufacturerIdentifier             497653 non-null  float64
#  41  Census_ProcessorModelIdentifier                    497651 non-null  float64
#  42  Census_ProcessorClass                              2082 non-null    object
#  43  Census_PrimaryDiskTotalCapacity                    497024 non-null  float64
#  44  Census_PrimaryDiskTypeName                         499291 non-null  object
#  45  Census_SystemVolumeTotalCapacity                   497024 non-null  float64
#  46  Census_HasOpticalDiskDrive                         500000 non-null  int64
#  47  Census_TotalPhysicalRAM                            495444 non-null  float64
#  48  Census_ChassisTypeName                             499963 non-null  object
#  49  Census_InternalPrimaryDiagonalDisplaySizeInInches  497346 non-null  float64
#  50  Census_InternalPrimaryDisplayResolutionHorizontal  497350 non-null  float64
#  51  Census_InternalPrimaryDisplayResolutionVertical    497350 non-null  float64
#  52  Census_PowerPlatformRoleName                       499998 non-null  object
#  53  Census_InternalBatteryType                         144397 non-null  object
#  54  Census_InternalBatteryNumberOfCharges              484962 non-null  float64
#  55  Census_OSVersion                                   500000 non-null  object
#  56  Census_OSArchitecture                              500000 non-null  object
#  57  Census_OSBranch                                    500000 non-null  object
#  58  Census_OSBuildNumber                               500000 non-null  int64
#  59  Census_OSBuildRevision                             500000 non-null  int64
#  60  Census_OSEdition                                   500000 non-null  object
#  61  Census_OSSkuName                                   500000 non-null  object
#  62  Census_OSInstallTypeName                           500000 non-null  object
#  63  Census_OSInstallLanguageIdentifier                 496668 non-null  float64
#  64  Census_OSUILocaleIdentifier                        500000 non-null  int64
#  65  Census_OSWUAutoUpdateOptionsName                   500000 non-null  object
#  66  Census_IsPortableOperatingSystem                   500000 non-null  int64
#  67  Census_GenuineStateName                            500000 non-null  object
#  68  Census_ActivationChannel                           500000 non-null  object
#  69  Census_IsFlightingInternal                         84775 non-null   float64
#  70  Census_IsFlightsDisabled                           491067 non-null  float64
#  71  Census_FlightRing                                  500000 non-null  object
#  72  Census_ThresholdOptIn                              181896 non-null  float64
#  73  Census_FirmwareManufacturerIdentifier              489651 non-null  float64
#  74  Census_FirmwareVersionIdentifier                   490939 non-null  float64
#  75  Census_IsSecureBootEnabled                         500000 non-null  int64
#  76  Census_IsWIMBootEnabled                            182334 non-null  float64
#  77  Census_IsVirtualDevice                             499099 non-null  float64
#  78  Census_IsTouchEnabled                              500000 non-null  int64
#  79  Census_IsPenCapable                                500000 non-null  int64
#  80  Census_IsAlwaysOnAlwaysConnectedCapable            495960 non-null  float64
#  81  Wdft_IsGamer                                       483050 non-null  float64
#  82  Wdft_RegionIdentifier                              483050 non-null  float64
#  83  HasDetections                                      500000 non-null  int64
# dtypes: float64(36), int64(18), object(30)
# memory usage: 320.4+ MB

# %%
df.describe().T
# Out:
#                                                         count            mean  \
# Unnamed: 0                                        500000.0000    4458888.2675
# IsBeta                                            500000.0000          0.0000
# RtpStateBitfield                                  498168.0000          6.8462
# IsSxsPassiveMode                                  500000.0000          0.0172
# DefaultBrowsersIdentifier                          24061.0000       1652.8245
# AVProductStatesIdentifier                         498062.0000      47850.9084
# AVProductsInstalled                               498062.0000          1.3268
# AVProductsEnabled                                 498062.0000          1.0207
# HasTpm                                            500000.0000          0.9878
# CountryIdentifier                                 500000.0000        108.0375
# CityIdentifier                                    481760.0000      81271.6460
# OrganizationIdentifier                            345437.0000         24.8699
# GeoNameIdentifier                                 499984.0000        169.7304
# LocaleEnglishNameIdentifier                       500000.0000        122.6110
# OsBuild                                           500000.0000      15726.9338
# OsSuite                                           500000.0000        574.7186
# IsProtected                                       498074.0000          0.9458
# AutoSampleOptIn                                   500000.0000          0.0000
# SMode                                             470152.0000          0.0004
# IeVerIdentifier                                   496791.0000        126.6626
# Firewall                                          494838.0000          0.9782
# UacLuaenable                                      499377.0000         13.7250
# Census_OEMNameIdentifier                          494619.0000       2218.6465
# Census_OEMModelIdentifier                         494236.0000     239128.0469
# Census_ProcessorCoreCount                         497653.0000          3.9941
# Census_ProcessorManufacturerIdentifier            497653.0000          4.5291
# Census_ProcessorModelIdentifier                   497651.0000       2370.9865
# Census_PrimaryDiskTotalCapacity                   497024.0000     514043.3159
# Census_SystemVolumeTotalCapacity                  497024.0000     378054.6393
# Census_HasOpticalDiskDrive                        500000.0000          0.0770
# Census_TotalPhysicalRAM                           495444.0000       6129.2322
# Census_InternalPrimaryDiagonalDisplaySizeInInches 497346.0000         16.6898
# Census_InternalPrimaryDisplayResolutionHorizontal 497350.0000       1548.3043
# Census_InternalPrimaryDisplayResolutionVertical   497350.0000        898.2393
# Census_InternalBatteryNumberOfCharges             484962.0000 1125600150.2055
# Census_OSBuildNumber                              500000.0000      15841.3726
# Census_OSBuildRevision                            500000.0000        967.2248
# Census_OSInstallLanguageIdentifier                496668.0000         14.6055
# Census_OSUILocaleIdentifier                       500000.0000         60.4463
# Census_IsPortableOperatingSystem                  500000.0000          0.0005
# Census_IsFlightingInternal                         84775.0000          0.0000
# Census_IsFlightsDisabled                          491067.0000          0.0000
# Census_ThresholdOptIn                             181896.0000          0.0003
# Census_FirmwareManufacturerIdentifier             489651.0000        402.6759
# Census_FirmwareVersionIdentifier                  490939.0000      33030.9889
# Census_IsSecureBootEnabled                        500000.0000          0.4854
# Census_IsWIMBootEnabled                           182334.0000          0.0000
# Census_IsVirtualDevice                            499099.0000          0.0071
# Census_IsTouchEnabled                             500000.0000          0.1254
# Census_IsPenCapable                               500000.0000          0.0377
# Census_IsAlwaysOnAlwaysConnectedCapable           495960.0000          0.0572
# Wdft_IsGamer                                      483050.0000          0.2841
# Wdft_RegionIdentifier                             483050.0000          7.8886
# HasDetections                                     500000.0000          0.4999
#
#                                                               std        min  \
# Unnamed: 0                                           2575618.6218     2.0000
# IsBeta                                                     0.0014     0.0000
# RtpStateBitfield                                           1.0230     0.0000
# IsSxsPassiveMode                                           0.1302     0.0000
# DefaultBrowsersIdentifier                               1004.7543     1.0000
# AVProductStatesIdentifier                              14023.0853     3.0000
# AVProductsInstalled                                        0.5230     1.0000
# AVProductsEnabled                                          0.1666     0.0000
# HasTpm                                                     0.1097     0.0000
# CountryIdentifier                                         63.0685     1.0000
# CityIdentifier                                         48985.1297     7.0000
# OrganizationIdentifier                                     5.6137     1.0000
# GeoNameIdentifier                                         89.3252     1.0000
# LocaleEnglishNameIdentifier                               69.3032     1.0000
# OsBuild                                                 2188.6461  7600.0000
# OsSuite                                                  248.2033    16.0000
# IsProtected                                                0.2264     0.0000
# AutoSampleOptIn                                            0.0053     0.0000
# SMode                                                      0.0209     0.0000
# IeVerIdentifier                                           42.6349     8.0000
# Firewall                                                   0.1459     0.0000
# UacLuaenable                                            8995.8481     0.0000
# Census_OEMNameIdentifier                                1315.7096    54.0000
# Census_OEMModelIdentifier                              72048.8836     1.0000
# Census_ProcessorCoreCount                                  2.0713     1.0000
# Census_ProcessorManufacturerIdentifier                     1.2896     1.0000
# Census_ProcessorModelIdentifier                          842.1367     3.0000
# Census_PrimaryDiskTotalCapacity                       370446.8159 10240.0000
# Census_SystemVolumeTotalCapacity                      338472.2187  9689.0000
# Census_HasOpticalDiskDrive                                 0.2666     0.0000
# Census_TotalPhysicalRAM                                 4964.5213   512.0000
# Census_InternalPrimaryDiagonalDisplaySizeInInches          5.9320     4.9000
# Census_InternalPrimaryDisplayResolutionHorizontal        368.5659    -1.0000
# Census_InternalPrimaryDisplayResolutionVertical          214.8625    -1.0000
# Census_InternalBatteryNumberOfCharges             1888768455.7804     0.0000
# Census_OSBuildNumber                                    1959.4403  9600.0000
# Census_OSBuildRevision                                  2920.6277     0.0000
# Census_OSInstallLanguageIdentifier                        10.2009     1.0000
# Census_OSUILocaleIdentifier                               45.0004     1.0000
# Census_IsPortableOperatingSystem                           0.0228     0.0000
# Census_IsFlightingInternal                                 0.0049     0.0000
# Census_IsFlightsDisabled                                   0.0038     0.0000
# Census_ThresholdOptIn                                      0.0161     0.0000
# Census_FirmwareManufacturerIdentifier                    221.5271    11.0000
# Census_FirmwareVersionIdentifier                       21220.1614    10.0000
# Census_IsSecureBootEnabled                                 0.4998     0.0000
# Census_IsWIMBootEnabled                                    0.0000     0.0000
# Census_IsVirtualDevice                                     0.0838     0.0000
# Census_IsTouchEnabled                                      0.3312     0.0000
# Census_IsPenCapable                                        0.1906     0.0000
# Census_IsAlwaysOnAlwaysConnectedCapable                    0.2323     0.0000
# Wdft_IsGamer                                               0.4510     0.0000
# Wdft_RegionIdentifier                                      4.5518     1.0000
# HasDetections                                              0.5000     0.0000
#
#                                                            25%          50%  \
# Unnamed: 0                                        2227692.5000 4461367.5000
# IsBeta                                                  0.0000       0.0000
# RtpStateBitfield                                        7.0000       7.0000
# IsSxsPassiveMode                                        0.0000       0.0000
# DefaultBrowsersIdentifier                             788.0000    1632.0000
# AVProductStatesIdentifier                           49480.0000   53447.0000
# AVProductsInstalled                                     1.0000       1.0000
# AVProductsEnabled                                       1.0000       1.0000
# HasTpm                                                  1.0000       1.0000
# CountryIdentifier                                      51.0000      97.0000
# CityIdentifier                                      36825.0000   82373.0000
# OrganizationIdentifier                                 18.0000      27.0000
# GeoNameIdentifier                                      89.0000     181.0000
# LocaleEnglishNameIdentifier                            74.0000      88.0000
# OsBuild                                             15063.0000   16299.0000
# OsSuite                                               256.0000     768.0000
# IsProtected                                             1.0000       1.0000
# AutoSampleOptIn                                         0.0000       0.0000
# SMode                                                   0.0000       0.0000
# IeVerIdentifier                                       111.0000     135.0000
# Firewall                                                1.0000       1.0000
# UacLuaenable                                            1.0000       1.0000
# Census_OEMNameIdentifier                             1443.0000    2102.0000
# Census_OEMModelIdentifier                          189641.7500  247520.0000
# Census_ProcessorCoreCount                               2.0000       4.0000
# Census_ProcessorManufacturerIdentifier                  5.0000       5.0000
# Census_ProcessorModelIdentifier                      1998.0000    2500.0000
# Census_PrimaryDiskTotalCapacity                    239372.0000  476940.0000
# Census_SystemVolumeTotalCapacity                   120775.0000  249450.0000
# Census_HasOpticalDiskDrive                              0.0000       0.0000
# Census_TotalPhysicalRAM                              4096.0000    4096.0000
# Census_InternalPrimaryDiagonalDisplaySizeInInches      13.9000      15.5000
# Census_InternalPrimaryDisplayResolutionHorizontal    1366.0000    1366.0000
# Census_InternalPrimaryDisplayResolutionVertical       768.0000     768.0000
# Census_InternalBatteryNumberOfCharges                   0.0000       0.0000
# Census_OSBuildNumber                                15063.0000   16299.0000
# Census_OSBuildRevision                                165.0000     285.0000
# Census_OSInstallLanguageIdentifier                      8.0000       9.0000
# Census_OSUILocaleIdentifier                            31.0000      34.0000
# Census_IsPortableOperatingSystem                        0.0000       0.0000
# Census_IsFlightingInternal                              0.0000       0.0000
# Census_IsFlightsDisabled                                0.0000       0.0000
# Census_ThresholdOptIn                                   0.0000       0.0000
# Census_FirmwareManufacturerIdentifier                 142.0000     500.0000
# Census_FirmwareVersionIdentifier                    13156.0000   33070.0000
# Census_IsSecureBootEnabled                              0.0000       0.0000
# Census_IsWIMBootEnabled                                 0.0000       0.0000
# Census_IsVirtualDevice                                  0.0000       0.0000
# Census_IsTouchEnabled                                   0.0000       0.0000
# Census_IsPenCapable                                     0.0000       0.0000
# Census_IsAlwaysOnAlwaysConnectedCapable                 0.0000       0.0000
# Wdft_IsGamer                                            0.0000       0.0000
# Wdft_RegionIdentifier                                   3.0000      10.0000
# HasDetections                                           0.0000       0.0000
#
#                                                               75%  \
# Unnamed: 0                                           6690936.0000
# IsBeta                                                     0.0000
# RtpStateBitfield                                           7.0000
# IsSxsPassiveMode                                           0.0000
# DefaultBrowsersIdentifier                               2381.0000
# AVProductStatesIdentifier                              53447.0000
# AVProductsInstalled                                        2.0000
# AVProductsEnabled                                          1.0000
# HasTpm                                                     1.0000
# CountryIdentifier                                        162.0000
# CityIdentifier                                        123939.5000
# OrganizationIdentifier                                    27.0000
# GeoNameIdentifier                                        267.0000
# LocaleEnglishNameIdentifier                              182.0000
# OsBuild                                                17134.0000
# OsSuite                                                  768.0000
# IsProtected                                                1.0000
# AutoSampleOptIn                                            0.0000
# SMode                                                      0.0000
# IeVerIdentifier                                          137.0000
# Firewall                                                   1.0000
# UacLuaenable                                               1.0000
# Census_OEMNameIdentifier                                2668.0000
# Census_OEMModelIdentifier                             304438.0000
# Census_ProcessorCoreCount                                  4.0000
# Census_ProcessorManufacturerIdentifier                     5.0000
# Census_ProcessorModelIdentifier                         2877.0000
# Census_PrimaryDiskTotalCapacity                       953869.0000
# Census_SystemVolumeTotalCapacity                      475981.0000
# Census_HasOpticalDiskDrive                                 0.0000
# Census_TotalPhysicalRAM                                 8192.0000
# Census_InternalPrimaryDiagonalDisplaySizeInInches         17.2000
# Census_InternalPrimaryDisplayResolutionHorizontal       1920.0000
# Census_InternalPrimaryDisplayResolutionVertical         1080.0000
# Census_InternalBatteryNumberOfCharges             4294967295.0000
# Census_OSBuildNumber                                   17134.0000
# Census_OSBuildRevision                                   547.0000
# Census_OSInstallLanguageIdentifier                        20.0000
# Census_OSUILocaleIdentifier                               90.0000
# Census_IsPortableOperatingSystem                           0.0000
# Census_IsFlightingInternal                                 0.0000
# Census_IsFlightsDisabled                                   0.0000
# Census_ThresholdOptIn                                      0.0000
# Census_FirmwareManufacturerIdentifier                    556.0000
# Census_FirmwareVersionIdentifier                       52436.0000
# Census_IsSecureBootEnabled                                 1.0000
# Census_IsWIMBootEnabled                                    0.0000
# Census_IsVirtualDevice                                     0.0000
# Census_IsTouchEnabled                                      0.0000
# Census_IsPenCapable                                        0.0000
# Census_IsAlwaysOnAlwaysConnectedCapable                    0.0000
# Wdft_IsGamer                                               1.0000
# Wdft_RegionIdentifier                                     11.0000
# HasDetections                                              1.0000
#
#                                                               max
# Unnamed: 0                                           8921471.0000
# IsBeta                                                     1.0000
# RtpStateBitfield                                          35.0000
# IsSxsPassiveMode                                           1.0000
# DefaultBrowsersIdentifier                               3209.0000
# AVProductStatesIdentifier                              70492.0000
# AVProductsInstalled                                        5.0000
# AVProductsEnabled                                          4.0000
# HasTpm                                                     1.0000
# CountryIdentifier                                        222.0000
# CityIdentifier                                        167958.0000
# OrganizationIdentifier                                    52.0000
# GeoNameIdentifier                                        296.0000
# LocaleEnglishNameIdentifier                              283.0000
# OsBuild                                                18242.0000
# OsSuite                                                  784.0000
# IsProtected                                                1.0000
# AutoSampleOptIn                                            1.0000
# SMode                                                      1.0000
# IeVerIdentifier                                          429.0000
# Firewall                                                   1.0000
# UacLuaenable                                         6357062.0000
# Census_OEMNameIdentifier                                6143.0000
# Census_OEMModelIdentifier                             345493.0000
# Census_ProcessorCoreCount                                 88.0000
# Census_ProcessorManufacturerIdentifier                    10.0000
# Census_ProcessorModelIdentifier                         4472.0000
# Census_PrimaryDiskTotalCapacity                     47687668.0000
# Census_SystemVolumeTotalCapacity                    47687100.0000
# Census_HasOpticalDiskDrive                                 1.0000
# Census_TotalPhysicalRAM                               393216.0000
# Census_InternalPrimaryDiagonalDisplaySizeInInches        142.0000
# Census_InternalPrimaryDisplayResolutionHorizontal      11520.0000
# Census_InternalPrimaryDisplayResolutionVertical         4320.0000
# Census_InternalBatteryNumberOfCharges             4294967295.0000
# Census_OSBuildNumber                                   18242.0000
# Census_OSBuildRevision                                 19069.0000
# Census_OSInstallLanguageIdentifier                        39.0000
# Census_OSUILocaleIdentifier                              162.0000
# Census_IsPortableOperatingSystem                           1.0000
# Census_IsFlightingInternal                                 1.0000
# Census_IsFlightsDisabled                                   1.0000
# Census_ThresholdOptIn                                      1.0000
# Census_FirmwareManufacturerIdentifier                   1084.0000
# Census_FirmwareVersionIdentifier                       72091.0000
# Census_IsSecureBootEnabled                                 1.0000
# Census_IsWIMBootEnabled                                    0.0000
# Census_IsVirtualDevice                                     1.0000
# Census_IsTouchEnabled                                      1.0000
# Census_IsPenCapable                                        1.0000
# Census_IsAlwaysOnAlwaysConnectedCapable                    1.0000
# Wdft_IsGamer                                               1.0000
# Wdft_RegionIdentifier                                     15.0000
# HasDetections                                              1.0000

# %% [markdown]
# ## Parte JUANFRAN

# %% [markdown]
# ### "Unnamed: 0"

# %%
df["Unnamed: 0"].value_counts()
# Out:
# Unnamed: 0
# 8427007    1
# 4076126    1
# 7315011    1
# 7257590    1
# 4851285    1
#           ..
# 3391674    1
# 6246089    1
# 42434      1
# 7181890    1
# 4295573    1
# Name: count, Length: 500000, dtype: int64

# %%
df["Unnamed: 0"].nunique()
# Out:
# 500000

# %% [markdown]
# Podemos ver que la columna "Unnamed: 0" contiene valores unicos que no se repiten, por lo que podemos suponer que a lo mejor puede ser algun tipo de indice interno que tiene la BBDD, por lo que prescindiremos de esta columna

# %%
del_columns.append("Unnamed: 0")

# %% [markdown]
# ### "MachineIdentifier"

# %%
df["MachineIdentifier"].value_counts()
# Out:
# MachineIdentifier
# f1cd864e97bae82bdf96523e1a539121    1
# 74f5f637add24668804961d81cca7697    1
# d1e0560ad7cd178b32599edb67142737    1
# d03a6fb0852e2ad3380e689a80d23273    1
# 8b3a780e6980a83b1650e7fc873dcfd1    1
#                                    ..
# 6154953dc05531cad9fb680cf39990b4    1
# b345b8ccc72ba43e7417b2018fb61444    1
# 013b44e10f97fa8f71b6b76e24323d51    1
# ce0e5ba490a2455a87d09184b9bbd578    1
# 7b45dc3537e17f16305c5983ca0a1cb9    1
# Name: count, Length: 500000, dtype: int64

# %%
df["MachineIdentifier"].nunique()
# Out:
# 500000

# %% [markdown]
# Podemos ver que en esta columna ocurre algo parecido, todos los valores son distintos y por el nombre de la columna podemos saber que contiene el identificador de los dispositivos, por lo que prescindiremos de esta columna

# %%
del_columns.append("MachineIdentifier")

# %% [markdown]
# ### "ProductName"

# %%
df["ProductName"].value_counts()
# Out:
# ProductName
# win8defender     494604
# mse                5395
# mseprerelease         1
# Name: count, dtype: int64

# %%
df["ProductName"].value_counts()/df.shape[0]  # càlculo de proporciones
# Out:
# ProductName
# win8defender    0.9892
# mse             0.0108
# mseprerelease   0.0000
# Name: count, dtype: float64

# %% [markdown]
# Podemos ver que tenemos 3 valores distintos, pero el valor win8defender aparece 98% de las veces

# %%
df["ProductName"].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### DELETE para ver

# %% [markdown]
# ### "EngineVersion"

# %%
df["EngineVersion"].value_counts().sort_index()
# Out:
# EngineVersion
# 1.1.10401.0         1
# 1.1.11701.0         3
# 1.1.12101.0         7
# 1.1.12400.0         1
# 1.1.12603.0         3
# 1.1.12706.0         1
# 1.1.12804.0         4
# 1.1.12805.0       115
# 1.1.12902.0       321
# 1.1.13000.0       220
# 1.1.13102.0         1
# 1.1.13103.0       235
# 1.1.13202.0       245
# 1.1.13303.0       516
# 1.1.13406.0         1
# 1.1.13407.0       479
# 1.1.13504.0      3876
# 1.1.13601.0       420
# 1.1.13701.0       255
# 1.1.13704.0       255
# 1.1.13802.0         4
# 1.1.13803.0         3
# 1.1.13804.0       513
# 1.1.13902.0         4
# 1.1.13903.0       515
# 1.1.14001.0         2
# 1.1.14002.0         2
# 1.1.14003.0       804
# 1.1.14102.0         2
# 1.1.14103.0         5
# 1.1.14104.0      5240
# 1.1.14201.0        11
# 1.1.14202.0       840
# 1.1.14303.0        10
# 1.1.14305.0       270
# 1.1.14306.0      1329
# 1.1.14405.2      1972
# 1.1.14500.2        19
# 1.1.14500.5      2591
# 1.1.14600.4      9005
# 1.1.14700.3        61
# 1.1.14700.4        65
# 1.1.14700.5      2593
# 1.1.14800.1        51
# 1.1.14800.3      7548
# 1.1.14901.3        71
# 1.1.14901.4     11984
# 1.1.15000.1       138
# 1.1.15000.2     14752
# 1.1.15100.1    205494
# 1.1.15200.1    216491
# 1.1.15300.5      3883
# 1.1.15300.6      6769
# Name: count, dtype: int64

# %% [markdown]
# Vemos que hay varios valores en esta columna, ahora comprobaremos si el EngineVersion tiene que ver con la columna ProductName

# %%
df[df["ProductName"] == "mse"]["EngineVersion"].value_counts()
# Out:
# EngineVersion
# 1.1.15200.1    2477
# 1.1.15100.1    2246
# 1.1.15000.2     223
# 1.1.14901.4     152
# 1.1.14800.3      84
# 1.1.15300.6      61
# 1.1.14700.5      33
# 1.1.14600.4      26
# 1.1.14306.0      25
# 1.1.14500.5      16
# 1.1.14405.2      14
# 1.1.14202.0      10
# 1.1.14305.0       6
# 1.1.14003.0       4
# 1.1.13601.0       2
# 1.1.13903.0       2
# 1.1.13804.0       2
# 1.1.14104.0       2
# 1.1.15300.5       1
# 1.1.13407.0       1
# 1.1.13000.0       1
# 1.1.13504.0       1
# 1.1.13202.0       1
# 1.1.12902.0       1
# 1.1.14700.4       1
# 1.1.13704.0       1
# 1.1.14800.1       1
# 1.1.14700.3       1
# Name: count, dtype: int64

# %%
df[df["EngineVersion"] == "1.1.15100.1"]
# Out:
#         Unnamed: 0                 MachineIdentifier   ProductName  \
# 0          8427007  f1cd864e97bae82bdf96523e1a539121  win8defender
# 1          8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender
# 2          2731904  4e628391e7cc7c482fb3286f486dbd25  win8defender
# 7           985557  1c4ec21828b563afb6b0aa72ef88926d  win8defender
# 8           387390  0b247aa88737776d0f88ce4dee447216  win8defender
# ...            ...                               ...           ...
# 499991     2159235  3df610b8bec46c7af0dd50c74756bf7e  win8defender
# 499993     7526638  d7f1b593177768d66a2905b09a43a4d5  win8defender
# 499996     5740034  a4c232d528d98343e8f1b73650da7b82  win8defender
# 499998     8713685  fa0841f8f6147de7c3d287e05270ed42  win8defender
# 499999     4295573  7b45dc3537e17f16305c5983ca0a1cb9  win8defender
#
#        EngineVersion        AppVersion  AvSigVersion  IsBeta  \
# 0        1.1.15100.1   4.18.1807.18075  1.273.1234.0       0
# 1        1.1.15100.1   4.18.1807.18075  1.273.1282.0       0
# 2        1.1.15100.1    4.9.10586.1106   1.273.781.0       0
# 7        1.1.15100.1   4.18.1806.18062   1.273.293.0       0
# 8        1.1.15100.1   4.18.1807.18075   1.273.418.0       0
# ...              ...               ...           ...     ...
# 499991   1.1.15100.1   4.18.1806.18062   1.273.520.0       0
# 499993   1.1.15100.1   4.18.1807.18075  1.273.1420.0       0
# 499996   1.1.15100.1   4.18.1807.18075  1.273.1620.0       0
# 499998   1.1.15100.1  4.14.17639.18041   1.273.483.0       0
# 499999   1.1.15100.1   4.18.1807.18075  1.273.1644.0       0
#
#         RtpStateBitfield  IsSxsPassiveMode  DefaultBrowsersIdentifier  ...  \
# 0                 7.0000                 0                        NaN  ...
# 1                 7.0000                 0                        NaN  ...
# 2                 7.0000                 0                        NaN  ...
# 7                 7.0000                 0                        NaN  ...
# 8                 7.0000                 0                        NaN  ...
# ...                  ...               ...                        ...  ...
# 499991            7.0000                 0                        NaN  ...
# 499993            7.0000                 0                        NaN  ...
# 499996            7.0000                 0                        NaN  ...
# 499998            7.0000                 0                        NaN  ...
# 499999            7.0000                 0                        NaN  ...
#
#         Census_FirmwareVersionIdentifier  Census_IsSecureBootEnabled  \
# 0                             19951.0000                           0
# 1                             48753.0000                           0
# 2                             33111.0000                           1
# 7                                    NaN                           0
# 8                             20106.0000                           1
# ...                                  ...                         ...
# 499991                        12303.0000                           1
# 499993                        12164.0000                           0
# 499996                               NaN                           0
# 499998                        11947.0000                           0
# 499999                        12103.0000                           0
#
#         Census_IsWIMBootEnabled  Census_IsVirtualDevice  \
# 0                           NaN                  0.0000
# 1                        0.0000                  0.0000
# 2                        0.0000                  0.0000
# 7                           NaN                  0.0000
# 8                           NaN                  0.0000
# ...                         ...                     ...
# 499991                      NaN                  0.0000
# 499993                   0.0000                  0.0000
# 499996                      NaN                  0.0000
# 499998                      NaN                  0.0000
# 499999                      NaN                  0.0000
#
#         Census_IsTouchEnabled  Census_IsPenCapable  \
# 0                           0                    0
# 1                           0                    0
# 2                           1                    1
# 7                           0                    0
# 8                           0                    0
# ...                       ...                  ...
# 499991                      0                    0
# 499993                      0                    0
# 499996                      0                    0
# 499998                      0                    0
# 499999                      0                    0
#
#         Census_IsAlwaysOnAlwaysConnectedCapable  Wdft_IsGamer  \
# 0                                        0.0000        0.0000
# 1                                        0.0000        1.0000
# 2                                        0.0000        0.0000
# 7                                        0.0000        0.0000
# 8                                        0.0000        0.0000
# ...                                         ...           ...
# 499991                                   0.0000        1.0000
# 499993                                   0.0000        0.0000
# 499996                                   0.0000        0.0000
# 499998                                   0.0000        0.0000
# 499999                                   0.0000        1.0000
#
#         Wdft_RegionIdentifier HasDetections
# 0                     11.0000             1
# 1                      3.0000             0
# 2                     15.0000             0
# 7                      7.0000             1
# 8                      3.0000             0
# ...                       ...           ...
# 499991                 3.0000             0
# 499993                 7.0000             0
# 499996                15.0000             0
# 499998                 1.0000             0
# 499999                 4.0000             1
#
# [205494 rows x 84 columns]

# %% [markdown]
# Por lo que podemos ver no tienen nada que ver por lo que puede llegar a ser interesante mantenerla, además, podríamos elimnar el ultimo número de la versión para poder agruparlas un poco más

# %%
df["EngineVersion"].str.rsplit(".", n=1).str[0]
# Out:
# 0         1.1.15100
# 1         1.1.15100
# 2         1.1.15100
# 3         1.1.15200
# 4         1.1.15200
#             ...
# 499995    1.1.15200
# 499996    1.1.15100
# 499997    1.1.15300
# 499998    1.1.15100
# 499999    1.1.15100
# Name: EngineVersion, Length: 500000, dtype: object

# %%
df["EngineVersion_trimmed"] = df["EngineVersion"].str.rsplit(".", n=1).str[0]
df["EngineVersion_trimmed"] = df["EngineVersion_trimmed"].str.rsplit(".", n=1).str[-1]

del_columns.append("EngineVersion")

# %%
df["EngineVersion_trimmed"].value_counts().sort_index()
# Out:
# EngineVersion_trimmed
# 10401         1
# 11701         3
# 12101         7
# 12400         1
# 12603         3
# 12706         1
# 12804         4
# 12805       115
# 12902       321
# 13000       220
# 13102         1
# 13103       235
# 13202       245
# 13303       516
# 13406         1
# 13407       479
# 13504      3876
# 13601       420
# 13701       255
# 13704       255
# 13802         4
# 13803         3
# 13804       513
# 13902         4
# 13903       515
# 14001         2
# 14002         2
# 14003       804
# 14102         2
# 14103         5
# 14104      5240
# 14201        11
# 14202       840
# 14303        10
# 14305       270
# 14306      1329
# 14405      1972
# 14500      2610
# 14600      9005
# 14700      2719
# 14800      7599
# 14901     12055
# 15000     14890
# 15100    205494
# 15200    216491
# 15300     10652
# Name: count, dtype: int64

# %% [markdown]
# ### "AppVersion"

# %%
df["AppVersion"].value_counts().sort_index()
# Out:
# AppVersion
# 4.10.14393.0       4399
# 4.10.14393.1066     404
# 4.10.14393.1198    1271
# 4.10.14393.1532       7
# 4.10.14393.1593     536
#                    ...
# 4.9.10586.873       228
# 4.9.10586.916       311
# 4.9.10586.962       262
# 4.9.10586.965       266
# 4.9.218.0           334
# Name: count, Length: 95, dtype: int64

# %%
df[df["ProductName"] == "mse"]["AppVersion"].value_counts()
# Out:
# AppVersion
# 4.10.209.0    4843
# 4.9.218.0      334
# 4.8.204.0       96
# 4.10.205.0      49
# 4.7.205.0       24
# 4.4.304.0       24
# 4.6.305.0       15
# 4.5.216.0       10
# Name: count, dtype: int64

# %%
df[df["AppVersion"] == "4.10.209.0"]
# Out:
#         Unnamed: 0                 MachineIdentifier   ProductName  \
# 87         3560007  662ca74a64aa88d371f2c7cfe6a2c890  win8defender
# 121         289101  0850c1e591b177e4e7bd3d7e73f050a4           mse
# 209        4540438  82511d4f7473708cd7bb3a7a7276931f  win8defender
# 222         455635  0d1a8a25d471a45a46acc6470e2ff39d           mse
# 223        7431707  d5380a5748ba45c8c126bdee0bdd5d0d           mse
# ...            ...                               ...           ...
# 499746      244927  070ad6da917516ea0691a8fb826f55b0           mse
# 499766     2878358  52969eef94139c8e49df6479830539f2           mse
# 499807     2878404  529703099031a605aba0b00ece4cac92  win8defender
# 499824     7150496  cd27813a5e444c0406f4b1d3e7cad827           mse
# 499851     5036960  908c99e617f11f8de3b1d5f77a69a6c7  win8defender
#
#        EngineVersion  AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 87       1.1.14405.2  4.10.209.0  1.259.1414.0       0            7.0000
# 121      1.1.15100.1  4.10.209.0  1.273.1826.0       0            7.0000
# 209      1.1.14901.3  4.10.209.0  1.267.1242.0       0            7.0000
# 222      1.1.15000.2  4.10.209.0   1.271.884.0       0            7.0000
# 223      1.1.15200.1  4.10.209.0   1.275.710.0       0            7.0000
# ...              ...         ...           ...     ...               ...
# 499746   1.1.15100.1  4.10.209.0   1.273.912.0       0            7.0000
# 499766   1.1.15200.1  4.10.209.0   1.275.725.0       0            7.0000
# 499807   1.1.15200.1  4.10.209.0  1.275.1478.0       0            7.0000
# 499824   1.1.15100.1  4.10.209.0    1.273.66.0       0            7.0000
# 499851   1.1.15200.1  4.10.209.0   1.275.810.0       0            7.0000
#
#         IsSxsPassiveMode  DefaultBrowsersIdentifier  ...  \
# 87                     0                   223.0000  ...
# 121                    0                        NaN  ...
# 209                    0                        NaN  ...
# 222                    0                        NaN  ...
# 223                    0                        NaN  ...
# ...                  ...                        ...  ...
# 499746                 0                        NaN  ...
# 499766                 0                        NaN  ...
# 499807                 0                        NaN  ...
# 499824                 0                        NaN  ...
# 499851                 0                        NaN  ...
#
#         Census_IsSecureBootEnabled  Census_IsWIMBootEnabled  \
# 87                               0                   0.0000
# 121                              0                   0.0000
# 209                              1                   0.0000
# 222                              0                   0.0000
# 223                              0                   0.0000
# ...                            ...                      ...
# 499746                           0                      NaN
# 499766                           0                      NaN
# 499807                           0                   0.0000
# 499824                           0                      NaN
# 499851                           1                   0.0000
#
#         Census_IsVirtualDevice  Census_IsTouchEnabled  Census_IsPenCapable  \
# 87                      0.0000                      0                    0
# 121                     0.0000                      0                    0
# 209                     0.0000                      0                    0
# 222                     0.0000                      0                    0
# 223                     0.0000                      0                    0
# ...                        ...                    ...                  ...
# 499746                  0.0000                      0                    0
# 499766                  0.0000                      0                    0
# 499807                  0.0000                      0                    0
# 499824                  0.0000                      0                    0
# 499851                  0.0000                      1                    1
#
#         Census_IsAlwaysOnAlwaysConnectedCapable  Wdft_IsGamer  \
# 87                                       0.0000        0.0000
# 121                                      0.0000        0.0000
# 209                                      0.0000        0.0000
# 222                                      0.0000        0.0000
# 223                                      0.0000        0.0000
# ...                                         ...           ...
# 499746                                   0.0000        0.0000
# 499766                                   0.0000        0.0000
# 499807                                   0.0000        0.0000
# 499824                                   0.0000        0.0000
# 499851                                   0.0000        0.0000
#
#         Wdft_RegionIdentifier  HasDetections EngineVersion_trimmed
# 87                    12.0000              1                 14405
# 121                    5.0000              1                 15100
# 209                   10.0000              1                 14901
# 222                   15.0000              0                 15000
# 223                    3.0000              0                 15200
# ...                       ...            ...                   ...
# 499746                12.0000              1                 15100
# 499766                15.0000              1                 15200
# 499807                15.0000              0                 15200
# 499824                 7.0000              1                 15100
# 499851                 1.0000              1                 15200
#
# [15292 rows x 85 columns]

# %% [markdown]
# Podemos ver que el AppVersion y el ProductName no tienen relación por lo que haremos lo mismo que con la columna EngineVersion

# %%
df["AppVersion_trimmed"] = df["AppVersion"].str.split(".").str[1]

del_columns.append("AppVersion")

# %%
df["EngineVersion_trimmed"].value_counts().sort_index()
# Out:
# EngineVersion_trimmed
# 10401         1
# 11701         3
# 12101         7
# 12400         1
# 12603         3
# 12706         1
# 12804         4
# 12805       115
# 12902       321
# 13000       220
# 13102         1
# 13103       235
# 13202       245
# 13303       516
# 13406         1
# 13407       479
# 13504      3876
# 13601       420
# 13701       255
# 13704       255
# 13802         4
# 13803         3
# 13804       513
# 13902         4
# 13903       515
# 14001         2
# 14002         2
# 14003       804
# 14102         2
# 14103         5
# 14104      5240
# 14201        11
# 14202       840
# 14303        10
# 14305       270
# 14306      1329
# 14405      1972
# 14500      2610
# 14600      9005
# 14700      2719
# 14800      7599
# 14901     12055
# 15000     14890
# 15100    205494
# 15200    216491
# 15300     10652
# Name: count, dtype: int64

# %% [markdown]
# ### "AvSigVersion"

# %%
df["AvSigVersion"].value_counts().sort_index()
# Out:
# AvSigVersion
# 0.0.0.0           4
# 1.169.55.0        1
# 1.199.1615.0      3
# 1.207.1891.0      1
# 1.207.2950.0      6
#                ...
# 1.277.51.0      411
# 1.277.58.0       76
# 1.277.62.0       80
# 1.277.64.0       60
# 1.277.67.0        7
# Name: count, Length: 6455, dtype: int64

# %%
df.groupby('AvSigVersion')['HasDetections'].mean().sort_values(ascending=False)
# Out:
# AvSigVersion
# 1.259.116.0    1.0000
# 1.229.460.0    1.0000
# 1.245.137.0    1.0000
# 1.245.1169.0   1.0000
# 1.245.1102.0   1.0000
#                 ...
# 1.247.913.0    0.0000
# 1.247.929.0    0.0000
# 1.247.93.0     0.0000
# 1.247.931.0    0.0000
# 0.0.0.0        0.0000
# Name: HasDetections, Length: 6455, dtype: float64

# %% [markdown]
# Vamos a comprobar cuantos de los valores terminan con ".0"

# %%
df[df["AvSigVersion"].str.endswith(".0")]["AvSigVersion"].count() / df.shape[0]
# Out:
# 1.0

# %% [markdown]
# Con este codigo filtro por los valores de la columna "AvSigVersion" que terminen en ".0" y cuento cuantos valores recupero y lo divido entre el total de filas del dataset.
#
# Y podemos ver que todos los valores de esta columna terminan con ".0" (el 100%), por lo que eliminaré el ".0"

# %%
df["AvSigVersion_trimmed"] = df["AvSigVersion"].str.rsplit(".", n=1).str[0]

del_columns.append("AvSigVersion")

# %%
df["AvSigVersion_trimmed"].value_counts().sort_index()
# Out:
# AvSigVersion_trimmed
# 0.0.0           4
# 1.169.55        1
# 1.199.1615      3
# 1.207.1891      1
# 1.207.2950      6
#              ...
# 1.277.51      411
# 1.277.58       76
# 1.277.62       80
# 1.277.64       60
# 1.277.67        7
# Name: count, Length: 6455, dtype: int64

# %% [markdown]
# Comprobamos que todos empiezan por 1.

# %%
df[~df['AvSigVersion_trimmed'].str.startswith("1.")]['AvSigVersion_trimmed']
# Out:
# 136234    0.0.0
# 337901    0.0.0
# 349972    0.0.0
# 434137    0.0.0
# Name: AvSigVersion_trimmed, dtype: object

# %% [markdown]
# Vemos que no empiezan con 1. y tienen de valor 0.0.0, por lo cual los eliminamos

# %%
df[df['AvSigVersion_trimmed'].str.startswith("1.")]['AvSigVersion_trimmed']
# Out:
# 0         1.273.1234
# 1         1.273.1282
# 2          1.273.781
# 3         1.275.1639
# 4          1.275.511
#              ...
# 499995    1.275.1090
# 499996    1.273.1620
# 499997    1.275.1343
# 499998     1.273.483
# 499999    1.273.1644
# Name: AvSigVersion_trimmed, Length: 499996, dtype: object

# %%
df = df[df['AvSigVersion_trimmed'].str.startswith("1.")]
df['AvSigVersion_trimmed'] = df['AvSigVersion_trimmed'].apply(lambda x: x.split(".")[1])
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_41132/3742774233.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AvSigVersion_trimmed'] = df['AvSigVersion_trimmed'].apply(lambda x: x.split(".")[1])

# %% [markdown]
# ### "IsBeta"

# %%
df["IsBeta"].value_counts()
# Out:
# IsBeta
# 0    499995
# 1         1
# Name: count, dtype: int64

# %% [markdown]
# Podemos ver que el valor True de "IsBeta" es tan solo 1 contra el resto de datos, por lo que prescendiremos de esta columna

# %%
del_columns.append("IsBeta")

# %% [markdown]
# ### "RtpStateBitfield"

# %%
df["RtpStateBitfield"].value_counts()
# Out:
# RtpStateBitfield
# 7.0000     484841
# 0.0000      10610
# 8.0000       1277
# 5.0000       1157
# 3.0000        175
# 1.0000        103
# 35.0000         1
# Name: count, dtype: int64

# %%
print(df[["RtpStateBitfield", "HasDetections"]].corr())
# Out:
#                   RtpStateBitfield  HasDetections
# RtpStateBitfield            1.0000         0.0403
# HasDetections               0.0403         1.0000

# %% [markdown]
# Por su baja correlación con el target prescindiremos de esta columna

# %%
del_columns.append("RtpStateBitfield")

# %% [markdown]
# ### "IsSxsPassiveMode"

# %%
df["IsSxsPassiveMode"].value_counts()
# Out:
# IsSxsPassiveMode
# 0    491375
# 1      8621
# Name: count, dtype: int64

# %%
df["IsSxsPassiveMode"].value_counts()/ df.shape[0]
# Out:
# IsSxsPassiveMode
# 0   0.9828
# 1   0.0172
# Name: count, dtype: float64

# %% [markdown]
# Podemos ver que el valor True de esta columna representa menos del 2% del dataframe

# %%
print(df[["IsSxsPassiveMode", "HasDetections"]].corr())
# Out:
#                   IsSxsPassiveMode  HasDetections
# IsSxsPassiveMode            1.0000        -0.0340
# HasDetections              -0.0340         1.0000

# %% [markdown]
# No esta balanceado y tiene una correlación debil con el target, por lo que prescindiremos de esta columna

# %%
del_columns.append("IsSxsPassiveMode")

# %% [markdown]
# ### "DefaultBrowsersIdentifier"

# %%
df["DefaultBrowsersIdentifier"].value_counts()
# Out:
# DefaultBrowsersIdentifier
# 239.0000     2589
# 3195.0000    2423
# 1632.0000    1601
# 3176.0000    1313
# 146.0000     1231
#              ...
# 2285.0000       1
# 2100.0000       1
# 2459.0000       1
# 2196.0000       1
# 1427.0000       1
# Name: count, Length: 554, dtype: int64

# %%
print(df[["DefaultBrowsersIdentifier", "HasDetections"]].corr())
# Out:
#                            DefaultBrowsersIdentifier  HasDetections
# DefaultBrowsersIdentifier                     1.0000         0.0010
# HasDetections                                 0.0010         1.0000

# %% [markdown]
# Por la baja correlación con el target, esta columna será eliminada

# %%
del_columns.append("DefaultBrowsersIdentifier")

# %% [markdown]
# ### "AVProductStatesIdentifier"

# %%
df["AVProductStatesIdentifier"].value_counts()
# Out:
# AVProductStatesIdentifier
# 53447.0000    326463
# 7945.0000      26642
# 47238.0000     18436
# 62773.0000     14931
# 46413.0000      6343
#                ...
# 2451.0000          1
# 19604.0000         1
# 3193.0000          1
# 26492.0000         1
# 18324.0000         1
# Name: count, Length: 5516, dtype: int64

# %%
print(df[["AVProductStatesIdentifier", "HasDetections"]].corr())
# Out:
#                            AVProductStatesIdentifier  HasDetections
# AVProductStatesIdentifier                     1.0000         0.1162
# HasDetections                                 0.1162         1.0000

# %% [markdown]
# Mantendremos la columna temporalmente y probaremos entrenar al modelo con y sin esta columna

# %% [markdown]
# Al mirar la info del dataset vimos que esta columna contenia nulos

# %%
df["AVProductStatesIdentifier"].isna().sum()/df.shape[0]
# Out:
# 0.003876031008248066

# %% [markdown]
# Podemos ver que menos del 1% de los datos en esta columna es nulo, por lo que borraremos las filas que contienen nulo

# %%
df.dropna(subset=["AVProductStatesIdentifier"], inplace=True)
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_41132/3301016493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["AVProductStatesIdentifier"], inplace=True)

# %%
df["AVProductStatesIdentifier"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### "AVProductsInstalled"

# %%
df["AVProductsInstalled"].value_counts()
# Out:
# AVProductsInstalled
# 1.0000    348046
# 2.0000    137852
# 3.0000     11617
# 4.0000       514
# 5.0000        29
# Name: count, dtype: int64

# %%
print(df[["AVProductsInstalled", "HasDetections"]].corr())
# Out:
#                      AVProductsInstalled  HasDetections
# AVProductsInstalled               1.0000        -0.1488
# HasDetections                    -0.1488         1.0000

# %% [markdown]
# Esta variable podría resultar interesante, aun siendo muy poca correlación negativa, es interesante ver que en algunos casos al tener más antivirus instalados pues se detectan menos virus

# %% [markdown]
# Anteriormente al mirar la info del dataset, vimos que esta columna tenía nulos

# %%
df["AVProductsInstalled"].isna().sum()
# Out:
# 0

# %% [markdown]
# Ahora contiene 0% de nulos, así que podemos suponer que las filas con nulos en la columna "AVProductStatesIdentifier" coincidian con las de esta columna, ya que ambas tenían 1938 nulos

# %%
df["AVProductsInstalled"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### "AVProductsEnabled"

# %%
df["AVProductsEnabled"].value_counts()
# Out:
# AVProductsEnabled
# 1.0000    485175
# 2.0000     11074
# 0.0000      1467
# 3.0000       316
# 4.0000        26
# Name: count, dtype: int64

# %%
print(df[["AVProductsEnabled", "HasDetections"]].corr())
# Out:
#                    AVProductsEnabled  HasDetections
# AVProductsEnabled             1.0000        -0.0419
# HasDetections                -0.0419         1.0000

# %%
print(df[["AVProductsEnabled", "AVProductsInstalled"]].corr())
# Out:
#                      AVProductsEnabled  AVProductsInstalled
# AVProductsEnabled               1.0000               0.2854
# AVProductsInstalled             0.2854               1.0000

# %% [markdown]
# Tiene muy baja relación con el target pero es algo más alta (casi 30%) de correlación con AVProductsInstalled, por lo que podemos mantenerla temporalmente y hacer pruebas

# %%
df["AVProductsEnabled"].isna().sum()/df.shape[0]
# Out:
# 0.0

# %% [markdown]
# Ahora contiene 0% de nulos, así que podemos suponer que las filas con nulos en las 2 ultimas columnas coincidian con las de esta columna, ya que las 3 tenían 1938 nulos

# %%
df["AVProductsEnabled"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### "HasTpm"

# %%
df["HasTpm"].value_counts()
# Out:
# HasTpm
# 1    492109
# 0      5949
# Name: count, dtype: int64

# %%
df["HasTpm"].value_counts()/df.shape[0]
# Out:
# HasTpm
# 1   0.9881
# 0   0.0119
# Name: count, dtype: float64

# %%
print(df[["HasTpm", "HasDetections"]].corr())
# Out:
#                HasTpm  HasDetections
# HasTpm         1.0000         0.0075
# HasDetections  0.0075         1.0000

# %% [markdown]
# Al ver que hay un fuerte desequilibrio en cuanto a los valores y que su correlación con el target es muy debil, prescindiremos de la columna

# %%
del_columns.append("HasTpm")

# %% [markdown]
# ### "CountryIdentifier"

# %%
df["CountryIdentifier"].value_counts()
# Out:
# CountryIdentifier
# 43     22278
# 29     19165
# 141    18349
# 93     16158
# 171    15683
#        ...
# 212       13
# 37        12
# 165       11
# 217       10
# 193        9
# Name: count, Length: 222, dtype: int64

# %%
print(df[["CountryIdentifier", "HasDetections"]].corr())
# Out:
#                    CountryIdentifier  HasDetections
# CountryIdentifier             1.0000         0.0066
# HasDetections                 0.0066         1.0000

# %% [markdown]
# Por la baja correlación con el target, esta columna será eliminada

# %%
del_columns.append("CountryIdentifier")

# %% [markdown]
# ### "CityIdentifier"

# %%
df["CityIdentifier"].value_counts()
# Out:
# CityIdentifier
# 130775.0000    5248
# 16668.0000     4727
# 82373.0000     4636
# 10222.0000     3995
# 61668.0000     3716
#                ...
# 83257.0000        1
# 99092.0000        1
# 81950.0000        1
# 96235.0000        1
# 148194.0000       1
# Name: count, Length: 37070, dtype: int64

# %%
df["CityIdentifier"].isna().sum()/df.shape[0]
# Out:
# 0.03647767930642616

# %%
print(df[["CityIdentifier", "HasDetections"]].corr())
# Out:
#                 CityIdentifier  HasDetections
# CityIdentifier          1.0000        -0.0046
# HasDetections          -0.0046         1.0000

# %% [markdown]
# Por la baja correlación con el target, esta columna será eliminada

# %%
del_columns.append("CityIdentifier")

# %% [markdown]
# ### "OrganizationIdentifier"

# %%
df["OrganizationIdentifier"].value_counts()
# Out:
# OrganizationIdentifier
# 27.0000    234042
# 18.0000     98471
# 48.0000      3643
# 50.0000      2529
# 37.0000      1030
# 11.0000      1028
# 49.0000       744
# 46.0000       638
# 14.0000       254
# 32.0000       224
# 36.0000       207
# 52.0000       173
# 33.0000       171
# 2.0000        153
# 5.0000        110
# 40.0000       100
# 28.0000        97
# 4.0000         78
# 10.0000        69
# 51.0000        52
# 1.0000         39
# 20.0000        38
# 8.0000         37
# 6.0000         25
# 31.0000        23
# 47.0000        22
# 22.0000        21
# 39.0000        21
# 3.0000         20
# 21.0000        19
# 16.0000        16
# 19.0000        10
# 29.0000         8
# 42.0000         8
# 7.0000          7
# 44.0000         6
# 26.0000         6
# 43.0000         4
# 45.0000         4
# 41.0000         2
# 35.0000         2
# 23.0000         2
# 25.0000         1
# 17.0000         1
# Name: count, dtype: int64

# %%
df["OrganizationIdentifier"].isna().sum()/df.shape[0]
# Out:
# 0.3090061800031322

# %% [markdown]
# Podemos ver que el 30% de esta columna es nulo, por lo que antes de valorar si eliminarla o no, comprobaremos su correlación con el target

# %%
print(df[["OrganizationIdentifier", "HasDetections"]].corr())
# Out:
#                         OrganizationIdentifier  HasDetections
# OrganizationIdentifier                  1.0000         0.0053
# HasDetections                           0.0053         1.0000

# %% [markdown]
# Al tener una correlación tan baja suponemos que la columna probablemente no tenga un impacto significativo, por lo que prescindiremos de la columna

# %%
del_columns.append("OrganizationIdentifier")

# %% [markdown]
# ### "GeoNameIdentifier"

# %%
df["GeoNameIdentifier"].value_counts()
# Out:
# GeoNameIdentifier
# 277.0000    85608
# 211.0000    23505
# 53.0000     22924
# 89.0000     20097
# 240.0000    19392
#             ...
# 280.0000        1
# 231.0000        1
# 113.0000        1
# 221.0000        1
# 132.0000        1
# Name: count, Length: 268, dtype: int64

# %%
print(df[["GeoNameIdentifier", "HasDetections"]].corr())
# Out:
#                    GeoNameIdentifier  HasDetections
# GeoNameIdentifier             1.0000         0.0037
# HasDetections                 0.0037         1.0000

# %% [markdown]
# Por la baja correlación con el target, esta columna será eliminada

# %%
del_columns.append("GeoNameIdentifier")

# %% [markdown]
# ### "LocaleEnglishNameIdentifier"

# %%
df["LocaleEnglishNameIdentifier"].value_counts()
# Out:
# LocaleEnglishNameIdentifier
# 75     117295
# 182     25092
# 42      22954
# 74      22824
# 88      20910
#         ...
# 152         1
# 155         1
# 165         1
# 190         1
# 127         1
# Name: count, Length: 233, dtype: int64

# %%
print(df[["LocaleEnglishNameIdentifier", "HasDetections"]].corr())
# Out:
#                              LocaleEnglishNameIdentifier  HasDetections
# LocaleEnglishNameIdentifier                       1.0000         0.0169
# HasDetections                                     0.0169         1.0000

# %% [markdown]
# Por la baja correlación con el target, esta columna será eliminada

# %%
del_columns.append("LocaleEnglishNameIdentifier")

# %% [markdown]
# ### "Platform"

# %%
df["Platform"].value_counts()
# Out:
# Platform
# windows10    482078
# windows8      10701
# windows7       5279
# Name: count, dtype: int64

# %%
df["Platform"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Aunque los valores estan muy desbalanceados, haremos pruebas y según los resultados de estas veremos si mantener o no la columna
#
# El siguiente punto será hacer un OHE con esta columna

# %%
df = pd.get_dummies(df, columns=["Platform"], prefix="Platform")

# %% [markdown]
# ### "Processor"

# %%
df["Processor"].value_counts()
# Out:
# Processor
# x64      452557
# x86       45487
# arm64        14
# Name: count, dtype: int64

# %%
df["Processor"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Aunque los valores estan desbalanceados, haremos pruebas y según los resultados de estas veremos si mantener o no la columna
#
# El siguiente punto será hacer un OHE con esta columna

# %%
df = df[df["Processor"]!="arm64"]

# %%
df['Processor'] = df['Processor'].apply(lambda x: 1 if x=="x86" else 0)

# %% [markdown]
# ## Parte MARC

# %%
list(df.columns[42:63])
# Out:
# ['Census_PrimaryDiskTotalCapacity',
#  'Census_PrimaryDiskTypeName',
#  'Census_SystemVolumeTotalCapacity',
#  'Census_HasOpticalDiskDrive',
#  'Census_TotalPhysicalRAM',
#  'Census_ChassisTypeName',
#  'Census_InternalPrimaryDiagonalDisplaySizeInInches',
#  'Census_InternalPrimaryDisplayResolutionHorizontal',
#  'Census_InternalPrimaryDisplayResolutionVertical',
#  'Census_PowerPlatformRoleName',
#  'Census_InternalBatteryType',
#  'Census_InternalBatteryNumberOfCharges',
#  'Census_OSVersion',
#  'Census_OSArchitecture',
#  'Census_OSBranch',
#  'Census_OSBuildNumber',
#  'Census_OSBuildRevision',
#  'Census_OSEdition',
#  'Census_OSSkuName',
#  'Census_OSInstallTypeName',
#  'Census_OSInstallLanguageIdentifier']

# %% [markdown]
# Columnas a revisar:
# ['Census_ProcessorClass',
#  'Census_PrimaryDiskTotalCapacity',
#  'Census_PrimaryDiskTypeName',
#  'Census_SystemVolumeTotalCapacity',
#  'Census_HasOpticalDiskDrive',
#  'Census_TotalPhysicalRAM',
#  'Census_ChassisTypeName',
#  'Census_InternalPrimaryDiagonalDisplaySizeInInches',
#  'Census_InternalPrimaryDisplayResolutionHorizontal',
#  'Census_InternalPrimaryDisplayResolutionVertical',
#  'Census_PowerPlatformRoleName',
#  'Census_InternalBatteryType',
#  'Census_InternalBatteryNumberOfCharges',
#  'Census_OSVersion',
#  'Census_OSArchitecture',
#  'Census_OSBranch',
#  'Census_OSBuildNumber',
#  'Census_OSBuildRevision',
#  'Census_OSEdition',
#  'Census_OSSkuName',
#  'Census_OSInstallTypeName']

# %%
len(df)
# Out:
# 498044

# %% [markdown]
# ### "Census_ProcessorClass"
# Descripción: "Clase" del procesador del dispositivo

# %%
df["Census_ProcessorClass"].value_counts(dropna=False)
# Out:
# Census_ProcessorClass
# NaN     495981
# mid       1186
# low        538
# high       339
# Name: count, dtype: int64

# %%
# 497_918 / 500_000 son nulos, por lo que eliminaremos la columna
del_columns.append("Census_ProcessorClass")

# %% [markdown]
# ### "Census_PrimaryDiskTotalCapacity"
# Descripción: Capacidad total del disco duro primario en MB

# %%
df["Census_PrimaryDiskTotalCapacity"].value_counts(dropna=False)
# Out:
# Census_PrimaryDiskTotalCapacity
# 476940.0000    158116
# 953869.0000    121790
# 305245.0000     26629
# 122104.0000     26424
# 244198.0000     25140
#                 ...
# 228818.0000         1
# 285148.0000         1
# 122069.0000         1
# 286254.0000         1
# 152499.0000         1
# Name: count, Length: 981, dtype: int64

# %%
# contamos nulos
df["Census_PrimaryDiskTotalCapacity"].isna().sum()  # 2968 nulos
# Out:
# 2968

# %%
# miramos la correlación con el target
df[["Census_PrimaryDiskTotalCapacity", "HasDetections"]].corr()
# Out:
#                                  Census_PrimaryDiskTotalCapacity  \
# Census_PrimaryDiskTotalCapacity                           1.0000
# HasDetections                                             0.0489
#
#                                  HasDetections
# Census_PrimaryDiskTotalCapacity         0.0489
# HasDetections                           1.0000

# %% [markdown]
# Difícilmente la capacidad del disco duro puede tener relación con la detección de malware, por lo que eliminaremos la columna.

# %%
del_columns.append("Census_PrimaryDiskTotalCapacity")

# %% [markdown]
# ### "Census_PrimaryDiskTypeName"
# Descripción: Tipo de disco duro primario

# %%
df["Census_PrimaryDiskTypeName"].value_counts(dropna=False)
# Out:
# Census_PrimaryDiskTypeName
# HDD            324325
# SSD            137913
# UNKNOWN         19513
# Unspecified     15584
# NaN               709
# Name: count, dtype: int64

# %%
# juntamos valores poco frecuentes (UNKKNOWN, Unspecified) a "Indefinido"
df["Census_PrimaryDiskTypeName"] = df["Census_PrimaryDiskTypeName"].replace(["UNKNOWN", "Unspecified"], "Indefinido")
# rellenamos nulos con "Indefinido"
df["Census_PrimaryDiskTypeName"] = df["Census_PrimaryDiskTypeName"].fillna("Indefinido")

# %%
df["Census_PrimaryDiskTypeName"].value_counts(dropna=False)
# Out:
# Census_PrimaryDiskTypeName
# HDD           324325
# SSD           137913
# Indefinido     35806
# Name: count, dtype: int64

# %% [markdown]
# Se propone realizar un OHE con esta columna.

# %%
df = pd.get_dummies(df, columns=["Census_PrimaryDiskTypeName"], prefix="Census_PrimaryDiskTypeName")  # TODO: revisar

# %% [markdown]
# ### "Census_SystemVolumeTotalCapacity"
# Descripción: Capacidad total del volumen del sistema en MB

# %%
df["Census_SystemVolumeTotalCapacity"].value_counts(dropna=False)
# Out:
# Census_SystemVolumeTotalCapacity
# NaN            2968
# 28542.0000     2920
# 926992.0000    2865
# 476389.0000    2377
# 476324.0000    2305
#                ...
# 429300.0000       1
# 434978.0000       1
# 128558.0000       1
# 202542.0000       1
# 470309.0000       1
# Name: count, Length: 141704, dtype: int64

# %%
# hacemos un histograma
df[df["Census_SystemVolumeTotalCapacity"] < 1_000_000]["Census_SystemVolumeTotalCapacity"].hist()
# Out:
# <Axes: >

# %%
# correlación con el target
df[["Census_SystemVolumeTotalCapacity", "HasDetections"]].corr()
# Out:
#                                   Census_SystemVolumeTotalCapacity  \
# Census_SystemVolumeTotalCapacity                            1.0000
# HasDetections                                               0.0137
#
#                                   HasDetections
# Census_SystemVolumeTotalCapacity         0.0137
# HasDetections                            1.0000

# %%
# mismo argumento que "Census_PrimaryDiskTotalCapacity", eliminamos la columna
del_columns.append("Census_SystemVolumeTotalCapacity")

# %% [markdown]
# ### "Census_HasOpticalDiskDrive"
# Descripción: Indica si el dispositivo tiene una unidad de disco óptico

# %%
df["Census_HasOpticalDiskDrive"].value_counts(dropna=False)
# Out:
# Census_HasOpticalDiskDrive
# 0    459692
# 1     38352
# Name: count, dtype: int64

# %%
38_517 / 500_000  # 7.7% True
# Out:
# 0.077034

# %%
# correlación con el target
df[["Census_HasOpticalDiskDrive", "HasDetections"]].corr()
# Out:
#                             Census_HasOpticalDiskDrive  HasDetections
# Census_HasOpticalDiskDrive                      1.0000         0.0199
# HasDetections                                   0.0199         1.0000

# %%
# TODO: Muy poca correlación, la dejamos pero la podríamos borrar perfectamente (dependerá de los resultados de los modelos)

# %% [markdown]
# ### "Census_TotalPhysicalRAM"
# Descripción: Cantidad de RAM física en MB

# %%
df["Census_TotalPhysicalRAM"].value_counts(dropna=False)
# Out:
# Census_TotalPhysicalRAM
# 4096.0000     227899
# 8192.0000     122853
# 2048.0000      61525
# 16384.0000     30014
# 6144.0000      22274
#                ...
# 3128.0000          1
# 6655.0000          1
# 1954.0000          1
# 3530.0000          1
# 4120.0000          1
# Name: count, Length: 526, dtype: int64

# %%
#  pasamos a GB
df["Census_TotalPhysicalRAM"].apply(lambda x: x // 1024).value_counts().sort_index()
# Out:
# Census_TotalPhysicalRAM
# 0.0000          40
# 1.0000        4208
# 2.0000       61933
# 3.0000        8947
# 4.0000      227958
# 5.0000         479
# 6.0000       22315
# 7.0000         317
# 8.0000      122864
# 9.0000          38
# 10.0000        601
# 11.0000         33
# 12.0000       9061
# 13.0000          2
# 14.0000         91
# 15.0000         44
# 16.0000      30018
# 18.0000         28
# 19.0000          4
# 20.0000        234
# 21.0000          2
# 22.0000          5
# 23.0000          4
# 24.0000        684
# 26.0000          1
# 27.0000          1
# 28.0000         13
# 29.0000          1
# 30.0000          2
# 31.0000          4
# 32.0000       3194
# 35.0000          1
# 36.0000          7
# 40.0000         18
# 44.0000          3
# 48.0000         50
# 52.0000          2
# 56.0000          2
# 60.0000          1
# 64.0000        309
# 66.0000          1
# 69.0000          1
# 72.0000          4
# 95.0000          1
# 96.0000          3
# 112.0000         1
# 128.0000        43
# 149.0000         1
# 192.0000         1
# 256.0000         4
# 384.0000         1
# Name: count, dtype: int64

# %%
"""
Opciones:
1. Eliminar la columna por (alomejor) no tener relación con el target
2. Eliminamos los registros con valores "anormales" o "poco frecuentes"
3. Otra (a definir)
"""

# OPCIÓN 2!
# convertimos a GB
df["Census_TotalPhysicalRAM_GB"] = df["Census_TotalPhysicalRAM"].apply(lambda x: x // 1024)

# %%
# nulos
df["Census_TotalPhysicalRAM_GB"].isna().sum()  # 4556 nulos
# Out:
# 4464

# %%
# Buscamos aquellos valores de RAM que tengan más de 1000 filas en caso de RAM < 20 GB y de más de 100 filas en caso de RAM >= 20 GB
recuento_RAM = df["Census_TotalPhysicalRAM_GB"].value_counts().sort_index()
a = recuento_RAM.iloc[:20][recuento_RAM.iloc[:20] > 1000] # RAM < 20 GB
b = recuento_RAM.iloc[20:][recuento_RAM.iloc[20:] > 100] # RAM >= 20 GB

# %%
ram_elecciones = a.index.tolist() + b.index.tolist()
ram_elecciones  # valores más frecuentes, nos quedamos con los registros que contenegan estos valores
# Out:
# [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 12.0, 16.0, 24.0, 32.0, 64.0]

# %%
# filtramos por los registros que tengan la RAM que hemos seleccionado
df = df[df["Census_TotalPhysicalRAM_GB"].isin(ram_elecciones)]  # indirecamente eliminamos los nulos

# %%
print(f"Recuento de registros actuales: {len(df)}")  # 493_254, 6746 menos
df["Census_TotalPhysicalRAM_GB"].value_counts()
# Out:
# Recuento de registros actuales: 491491
# Census_TotalPhysicalRAM_GB
# 4.0000     227958
# 8.0000     122864
# 2.0000      61933
# 16.0000     30018
# 6.0000      22315
# 12.0000      9061
# 3.0000       8947
# 1.0000       4208
# 32.0000      3194
# 24.0000       684
# 64.0000       309
# Name: count, dtype: int64

# %%
# correlación con el target
df[["Census_TotalPhysicalRAM_GB", "HasDetections"]].corr()
# Out:
#                             Census_TotalPhysicalRAM_GB  HasDetections
# Census_TotalPhysicalRAM_GB                      1.0000         0.0686
# HasDetections                                   0.0686         1.0000

# %%
del_columns.append("Census_TotalPhysicalRAM")

# %% [markdown]
# ### "Census_ChassisTypeName"
# Descripción: Tipo de chasis del dispositivo

# %%
df["Census_ChassisTypeName"].value_counts(dropna=False)
# Out:
# Census_ChassisTypeName
# Notebook               291606
# Desktop                102887
# Laptop                  37942
# Portable                20028
# AllinOne                11324
# MiniTower                4691
# Convertible              4650
# Other                    3135
# Detachable               2911
# LowProfileDesktop        2840
# HandHeld                 2647
# UNKNOWN                  2243
# SpaceSaving              1662
# Tablet                    725
# Tower                     560
# Unknown                   551
# MainServerChassis         420
# MiniPC                    255
# LunchBox                  221
# SubNotebook                45
# BusExpansionChassis        38
# RackMountChassis           36
# NaN                        35
# 30                         11
# StickPC                     7
# 0                           5
# 35                          3
# PizzaBox                    3
# MultisystemChassis          2
# 31                          2
# SubChassis                  2
# 32                          1
# ExpansionChassis            1
# Blade                       1
# 25                          1
# Name: count, dtype: int64

# %%
# Convertir la variable string en variables dummy
df_dummies = pd.get_dummies(df['Census_ChassisTypeName'], prefix='Census_ChassisTypeName')

# Calcular la correlación de cada variable dummy con el target
correlations = df_dummies.corrwith(df['HasDetections'])

correlations
# Out:
# Census_ChassisTypeName_0                     -0.0006
# Census_ChassisTypeName_25                    -0.0014
# Census_ChassisTypeName_30                    -0.0022
# Census_ChassisTypeName_31                     0.0020
# Census_ChassisTypeName_32                     0.0014
# Census_ChassisTypeName_35                    -0.0008
# Census_ChassisTypeName_AllinOne               0.0034
# Census_ChassisTypeName_Blade                 -0.0014
# Census_ChassisTypeName_BusExpansionChassis   -0.0019
# Census_ChassisTypeName_Convertible           -0.0039
# Census_ChassisTypeName_Desktop                0.0255
# Census_ChassisTypeName_Detachable            -0.0234
# Census_ChassisTypeName_ExpansionChassis      -0.0014
# Census_ChassisTypeName_HandHeld              -0.0302
# Census_ChassisTypeName_Laptop                -0.0044
# Census_ChassisTypeName_LowProfileDesktop      0.0021
# Census_ChassisTypeName_LunchBox              -0.0017
# Census_ChassisTypeName_MainServerChassis     -0.0050
# Census_ChassisTypeName_MiniPC                -0.0074
# Census_ChassisTypeName_MiniTower              0.0064
# Census_ChassisTypeName_MultisystemChassis    -0.0000
# Census_ChassisTypeName_Notebook              -0.0001
# Census_ChassisTypeName_Other                 -0.0335
# Census_ChassisTypeName_PizzaBox              -0.0008
# Census_ChassisTypeName_Portable              -0.0081
# Census_ChassisTypeName_RackMountChassis      -0.0048
# Census_ChassisTypeName_SpaceSaving           -0.0024
# Census_ChassisTypeName_StickPC               -0.0038
# Census_ChassisTypeName_SubChassis            -0.0000
# Census_ChassisTypeName_SubNotebook           -0.0023
# Census_ChassisTypeName_Tablet                -0.0108
# Census_ChassisTypeName_Tower                  0.0006
# Census_ChassisTypeName_UNKNOWN               -0.0096
# Census_ChassisTypeName_Unknown               -0.0046
# dtype: float64

# %%
# Correlaciones < 0.04 -> proponemos eliminar la columna
del_columns.append("Census_ChassisTypeName")

# %%
df.head(2)
# Out:
#    Unnamed: 0                 MachineIdentifier   ProductName EngineVersion  \
# 0     8427007  f1cd864e97bae82bdf96523e1a539121  win8defender   1.1.15100.1
# 1     8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender   1.1.15100.1
#
#         AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 0  4.18.1807.18075  1.273.1234.0       0            7.0000                 0
# 1  4.18.1807.18075  1.273.1282.0       0            7.0000                 0
#
#    DefaultBrowsersIdentifier  ...  EngineVersion_trimmed  AppVersion_trimmed  \
# 0                        NaN  ...                  15100                  18
# 1                        NaN  ...                  15100                  18
#
#    AvSigVersion_trimmed  Platform_windows10  Platform_windows7  \
# 0                   273                True              False
# 1                   273                True              False
#
#    Platform_windows8  Census_PrimaryDiskTypeName_HDD  \
# 0              False                            True
# 1              False                            True
#
#    Census_PrimaryDiskTypeName_Indefinido  Census_PrimaryDiskTypeName_SSD  \
# 0                                  False                           False
# 1                                  False                           False
#
#    Census_TotalPhysicalRAM_GB
# 0                      8.0000
# 1                      8.0000
#
# [2 rows x 92 columns]

# %% [markdown]
# ### "Census_InternalPrimaryDiagonalDisplaySizeInInches"
# Descripción: Tamaño diagonal de la pantalla en pulgadas

# %%
df["Census_InternalPrimaryDiagonalDisplaySizeInInches"].value_counts(dropna=False)
# Out:
# Census_InternalPrimaryDiagonalDisplaySizeInInches
# 15.5000    169360
# 13.9000     52292
# 14.0000     30073
# 11.6000     17350
# 21.5000     15104
#             ...
# 69.3000         1
# 29.6000         1
# 85.8000         1
# 60.2000         1
# 95.4000         1
# Name: count, Length: 512, dtype: int64

# %%
# hist
df["Census_InternalPrimaryDiagonalDisplaySizeInInches"].hist()
# Out:
# <Axes: >

# %%
# se deduce una muy baja correlación con el target, eliminamos la columna  # TODO
del_columns.append("Census_InternalPrimaryDiagonalDisplaySizeInInches")

# %%
# correlación con el target
df[["Census_InternalPrimaryDiagonalDisplaySizeInInches", "HasDetections"]].corr()
# Out:
#                                                    Census_InternalPrimaryDiagonalDisplaySizeInInches  \
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                             1.0000
# HasDetections                                                                                 0.0334
#
#                                                    HasDetections
# Census_InternalPrimaryDiagonalDisplaySizeInInches         0.0334
# HasDetections                                             1.0000

# %% [markdown]
# ### "Census_InternalPrimaryDisplayResolutionHorizontal" y "Census_InternalPrimaryDisplayResolutionVertical"
# Descripción: Resolución de la pantalla

# %%
df["Census_InternalPrimaryDisplayResolutionHorizontal"].value_counts(dropna=False)
# Out:
# Census_InternalPrimaryDisplayResolutionHorizontal
# 1366.0000     249060
# 1920.0000     122787
# 1280.0000      29108
# 1600.0000      27791
# 1024.0000      18484
#                ...
# 5110.0000          1
# 1282.0000          1
# 1173.0000          1
# 3780.0000          1
# 10320.0000         1
# Name: count, Length: 374, dtype: int64

# %%
df["Census_InternalPrimaryDisplayResolutionVertical"].value_counts(dropna=False)
# Out:
# Census_InternalPrimaryDisplayResolutionVertical
# 768.0000     273860
# 1080.0000    118997
# 900.0000      36251
# 800.0000      14531
# 1024.0000     10268
#               ...
# 1364.0000         1
# 739.0000          1
# 1326.0000         1
# 2220.0000         1
# 759.0000          1
# Name: count, Length: 400, dtype: int64

# %%
# misma argumentación que "Census_InternalPrimaryDiagonalDisplaySizeInInches", proponemos eliminar las columnas
del_columns.append("Census_InternalPrimaryDisplayResolutionHorizontal")
del_columns.append("Census_InternalPrimaryDisplayResolutionVertical")

# %% [markdown]
# ### "Census_PowerPlatformRoleName"
# Descripción: Nombre del rol de la plataforma de energía

# %%
df["Census_PowerPlatformRoleName"].value_counts(dropna=False)  # no tiene nulos
# Out:
# Census_PowerPlatformRoleName
# Mobile               342396
# Desktop              113022
# Slate                 27331
# Workstation            6036
# SOHOServer             1999
# UNKNOWN                 361
# AppliancePC             212
# EnterpriseServer        131
# PerformanceServer         3
# Name: count, dtype: int64

# %%
# juntamos columnas [SOHOServer, EnterpriseServer, PerformanceServer] en "Server"
df["Census_PowerPlatformRoleName"] = df["Census_PowerPlatformRoleName"].replace(["SOHOServer", "EnterpriseServer", "PerformanceServer"], "Server")

# %%
# borramos registros con nulos (con valor UNKNOWN)
df = df[df["Census_PowerPlatformRoleName"] != "UNKNOWN"]

# %%
df["Census_PowerPlatformRoleName"].value_counts(dropna=False)
# Out:
# Census_PowerPlatformRoleName
# Mobile         342396
# Desktop        113022
# Slate           27331
# Workstation      6036
# Server           2133
# AppliancePC       212
# Name: count, dtype: int64

# %%
# hay únicamente 9 valores únicos, es una variable categórica, proponemos hacer un OHE
df = pd.get_dummies(df, columns=["Census_PowerPlatformRoleName"], prefix="Census_PowerPlatformRoleName")  # TODO

# %% [markdown]
# ### "Census_InternalBatteryType"
# Descripción: Tipo de batería interna

# %%
df["Census_InternalBatteryType"].value_counts(dropna=False)
# Out:
# Census_InternalBatteryType
# NaN     348469
# lion    112321
# li-i     13737
# #         9904
# lip       3302
# liio      1771
# li p       460
# li         348
# nimh       267
# real       162
# bq20       142
# pbac       128
# lgi0        29
# unkn        19
# lipo        13
# lhp0        12
# vbox        11
# ithi         7
# 4cel         6
# ram          5
# batt         3
# bad          3
# lipp         3
# a132         2
# virt         2
# li-l         1
# lgl0         1
# icp3         1
# 3ion         1
# Name: count, dtype: int64

# %%
# interpeteción: hay 348_471 nulos y se puede presuponer una alta correlación entre el tipo de batería y el tipo de dispositivo -> eliminamos la columna #TODO: comprobar
del_columns.append("Census_InternalBatteryType")

# %% [markdown]
# ### "Census_InternalBatteryNumberOfCharges"
# Descripción: Número de cargas de la batería interna

# %%
df["Census_InternalBatteryNumberOfCharges"].value_counts(dropna=False)
# Out:
# Census_InternalBatteryNumberOfCharges
# 0.0000             280522
# 4294967295.0000    123590
# NaN                 12204
# 1.0000               2926
# 2.0000               1488
#                     ...
# 33134.0000              1
# 1182.0000               1
# 53770.0000              1
# 10658.0000              1
# 1900.0000               1
# Name: count, Length: 5233, dtype: int64

# %%
# 1. se presupone que serà una variable contínua
# 2. nulos: hay directamente 12204 NaNs (2.5%) pero se observa unos registros extremadamente altos de 4294967295 y 4294967294. Estos valores provienen de un error en la recogida de datos, 4294967295 es el valor máximo de un entero de 32 bits (2^32 - 1). Hay 123_658 y 656 registros respectivamente (24.9% y 0.1%). Demasiados registros para eliminarlos, se propone rellenar los nulos con la media de la columna.

# TODO: exponer al grupo
# calculamos media evitando los valores erróneos

df["Census_InternalBatteryNumberOfCharges"] = df["Census_InternalBatteryNumberOfCharges"].fillna(0)

# %%
# vamos los registros fallidos
df[df["Census_InternalBatteryNumberOfCharges"] > 4_000_000_000]
# observamos que los registros con valor 4294967295 son los que tienen nulos en la columna "Census_InternalBatteryType" -> comportamiento esperado
# Out:
#         Unnamed: 0                 MachineIdentifier   ProductName  \
# 0          8427007  f1cd864e97bae82bdf96523e1a539121  win8defender
# 10          844555  1843aa258152c018f0298a8ba9915ebd  win8defender
# 12         2382707  4458ad1edb42d5f05ac868afa37f628e  win8defender
# 16         5951649  aad1e798db865780f340539c0429934d  win8defender
# 19         2797061  503ff9f5e17315afd880eb6745316439  win8defender
# ...            ...                               ...           ...
# 499979     5253164  96c417e49191b49f11c51314fe27e5c4  win8defender
# 499988      959036  1b8d39b74872ef5de9f9c9ca43424d79  win8defender
# 499994     5802201  a687cfd1252ee03ce9658eaf15bdf40e  win8defender
# 499997     8819786  fd16cd542d660848d272e4552bcccb1e  win8defender
# 499999     4295573  7b45dc3537e17f16305c5983ca0a1cb9  win8defender
#
#        EngineVersion       AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 0        1.1.15100.1  4.18.1807.18075  1.273.1234.0       0            7.0000
# 10       1.1.15100.1  4.18.1807.18075  1.273.1552.0       0            7.0000
# 12       1.1.15100.1  4.18.1807.18075  1.273.1112.0       0            7.0000
# 16       1.1.15100.1  4.18.1806.18062   1.273.356.0       0            7.0000
# 19       1.1.15200.1  4.18.1807.18075   1.275.948.0       0            7.0000
# ...              ...              ...           ...     ...               ...
# 499979   1.1.15200.1  4.18.1807.18075  1.275.1140.0       0            7.0000
# 499988   1.1.15200.1  4.18.1807.18075   1.275.260.0       0            7.0000
# 499994   1.1.15200.1   4.9.10586.1106   1.275.155.0       0            7.0000
# 499997   1.1.15300.5   4.13.17134.112  1.275.1343.0       0            7.0000
# 499999   1.1.15100.1  4.18.1807.18075  1.273.1644.0       0            7.0000
#
#         IsSxsPassiveMode  DefaultBrowsersIdentifier  ...  \
# 0                      0                        NaN  ...
# 10                     0                        NaN  ...
# 12                     0                        NaN  ...
# 16                     0                        NaN  ...
# 19                     0                        NaN  ...
# ...                  ...                        ...  ...
# 499979                 0                        NaN  ...
# 499988                 0                        NaN  ...
# 499994                 0                  2132.0000  ...
# 499997                 0                        NaN  ...
# 499999                 0                        NaN  ...
#
#         Census_PrimaryDiskTypeName_HDD  Census_PrimaryDiskTypeName_Indefinido  \
# 0                                 True                                  False
# 10                               False                                  False
# 12                                True                                  False
# 16                                True                                  False
# 19                               False                                   True
# ...                                ...                                    ...
# 499979                            True                                  False
# 499988                           False                                   True
# 499994                            True                                  False
# 499997                            True                                  False
# 499999                           False                                  False
#
#         Census_PrimaryDiskTypeName_SSD  Census_TotalPhysicalRAM_GB  \
# 0                                False                      8.0000
# 10                                True                      4.0000
# 12                               False                      4.0000
# 16                               False                      4.0000
# 19                               False                      4.0000
# ...                                ...                         ...
# 499979                           False                      3.0000
# 499988                           False                      4.0000
# 499994                           False                      4.0000
# 499997                           False                      4.0000
# 499999                            True                     16.0000
#
#         Census_PowerPlatformRoleName_AppliancePC  \
# 0                                          False
# 10                                         False
# 12                                         False
# 16                                         False
# 19                                         False
# ...                                          ...
# 499979                                     False
# 499988                                     False
# 499994                                     False
# 499997                                     False
# 499999                                     False
#
#         Census_PowerPlatformRoleName_Desktop  \
# 0                                       True
# 10                                      True
# 12                                      True
# 16                                      True
# 19                                      True
# ...                                      ...
# 499979                                  True
# 499988                                  True
# 499994                                 False
# 499997                                  True
# 499999                                  True
#
#         Census_PowerPlatformRoleName_Mobile  \
# 0                                     False
# 10                                    False
# 12                                    False
# 16                                    False
# 19                                    False
# ...                                     ...
# 499979                                False
# 499988                                False
# 499994                                 True
# 499997                                False
# 499999                                False
#
#         Census_PowerPlatformRoleName_Server  \
# 0                                     False
# 10                                    False
# 12                                    False
# 16                                    False
# 19                                    False
# ...                                     ...
# 499979                                False
# 499988                                False
# 499994                                False
# 499997                                False
# 499999                                False
#
#         Census_PowerPlatformRoleName_Slate  \
# 0                                    False
# 10                                   False
# 12                                   False
# 16                                   False
# 19                                   False
# ...                                    ...
# 499979                               False
# 499988                               False
# 499994                               False
# 499997                               False
# 499999                               False
#
#         Census_PowerPlatformRoleName_Workstation
# 0                                          False
# 10                                         False
# 12                                         False
# 16                                         False
# 19                                         False
# ...                                          ...
# 499979                                     False
# 499988                                     False
# 499994                                     False
# 499997                                     False
# 499999                                     False
#
# [124246 rows x 97 columns]

# %%
# se imputan los valores erróneos con la media
mask = df["Census_InternalBatteryNumberOfCharges"] > 4_000_000_000
df.loc[mask, "Census_InternalBatteryNumberOfCharges"] = 0

# %%
# hist
df["Census_InternalBatteryNumberOfCharges"].hist()
# Out:
# <Axes: >

# %%
df['Census_InternalBatteryNumberOfCharges'].value_counts(dropna=False)
# Out:
# Census_InternalBatteryNumberOfCharges
# 0.0000        416972
# 1.0000          2926
# 2.0000          1488
# 16.0000         1487
# 3.0000          1208
#                ...
# 8331.0000          1
# 57727.0000         1
# 1030.0000          1
# 43544.0000         1
# 1900.0000          1
# Name: count, Length: 5230, dtype: int64

# %%
# miramos registros con valor 0
df[df["Census_InternalBatteryNumberOfCharges"] == 0]
# Out:
#         Unnamed: 0                 MachineIdentifier   ProductName  \
# 0          8427007  f1cd864e97bae82bdf96523e1a539121  win8defender
# 1          8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender
# 2          2731904  4e628391e7cc7c482fb3286f486dbd25  win8defender
# 4           236059  06ca8fa8d32c2abdc5b3577d676b3269  win8defender
# 5          3771983  6c3ff3036d3ecc96729a615653742608  win8defender
# ...            ...                               ...           ...
# 499995     5826339  a739cacc292f3f1e745827c1ca6c6ada  win8defender
# 499996     5740034  a4c232d528d98343e8f1b73650da7b82  win8defender
# 499997     8819786  fd16cd542d660848d272e4552bcccb1e  win8defender
# 499998     8713685  fa0841f8f6147de7c3d287e05270ed42  win8defender
# 499999     4295573  7b45dc3537e17f16305c5983ca0a1cb9  win8defender
#
#        EngineVersion        AppVersion  AvSigVersion  IsBeta  \
# 0        1.1.15100.1   4.18.1807.18075  1.273.1234.0       0
# 1        1.1.15100.1   4.18.1807.18075  1.273.1282.0       0
# 2        1.1.15100.1    4.9.10586.1106   1.273.781.0       0
# 4        1.1.15200.1   4.18.1807.18075   1.275.511.0       0
# 5        1.1.15200.1   4.18.1807.18075   1.275.981.0       0
# ...              ...               ...           ...     ...
# 499995   1.1.15200.1   4.18.1807.18075  1.275.1090.0       0
# 499996   1.1.15100.1   4.18.1807.18075  1.273.1620.0       0
# 499997   1.1.15300.5    4.13.17134.112  1.275.1343.0       0
# 499998   1.1.15100.1  4.14.17639.18041   1.273.483.0       0
# 499999   1.1.15100.1   4.18.1807.18075  1.273.1644.0       0
#
#         RtpStateBitfield  IsSxsPassiveMode  DefaultBrowsersIdentifier  ...  \
# 0                 7.0000                 0                        NaN  ...
# 1                 7.0000                 0                        NaN  ...
# 2                 7.0000                 0                        NaN  ...
# 4                 7.0000                 0                        NaN  ...
# 5                 7.0000                 0                        NaN  ...
# ...                  ...               ...                        ...  ...
# 499995            7.0000                 0                        NaN  ...
# 499996            7.0000                 0                        NaN  ...
# 499997            7.0000                 0                        NaN  ...
# 499998            7.0000                 0                        NaN  ...
# 499999            7.0000                 0                        NaN  ...
#
#         Census_PrimaryDiskTypeName_HDD  Census_PrimaryDiskTypeName_Indefinido  \
# 0                                 True                                  False
# 1                                 True                                  False
# 2                                False                                  False
# 4                                 True                                  False
# 5                                 True                                  False
# ...                                ...                                    ...
# 499995                            True                                  False
# 499996                           False                                  False
# 499997                            True                                  False
# 499998                            True                                  False
# 499999                           False                                  False
#
#         Census_PrimaryDiskTypeName_SSD  Census_TotalPhysicalRAM_GB  \
# 0                                False                      8.0000
# 1                                False                      8.0000
# 2                                 True                      8.0000
# 4                                False                      4.0000
# 5                                False                      4.0000
# ...                                ...                         ...
# 499995                           False                      4.0000
# 499996                            True                      8.0000
# 499997                           False                      4.0000
# 499998                           False                      6.0000
# 499999                            True                     16.0000
#
#         Census_PowerPlatformRoleName_AppliancePC  \
# 0                                          False
# 1                                          False
# 2                                          False
# 4                                          False
# 5                                          False
# ...                                          ...
# 499995                                     False
# 499996                                     False
# 499997                                     False
# 499998                                     False
# 499999                                     False
#
#         Census_PowerPlatformRoleName_Desktop  \
# 0                                       True
# 1                                      False
# 2                                      False
# 4                                      False
# 5                                      False
# ...                                      ...
# 499995                                 False
# 499996                                 False
# 499997                                  True
# 499998                                 False
# 499999                                  True
#
#         Census_PowerPlatformRoleName_Mobile  \
# 0                                     False
# 1                                      True
# 2                                      True
# 4                                      True
# 5                                      True
# ...                                     ...
# 499995                                 True
# 499996                                 True
# 499997                                False
# 499998                                 True
# 499999                                False
#
#         Census_PowerPlatformRoleName_Server  \
# 0                                     False
# 1                                     False
# 2                                     False
# 4                                     False
# 5                                     False
# ...                                     ...
# 499995                                False
# 499996                                False
# 499997                                False
# 499998                                False
# 499999                                False
#
#         Census_PowerPlatformRoleName_Slate  \
# 0                                    False
# 1                                    False
# 2                                    False
# 4                                    False
# 5                                    False
# ...                                    ...
# 499995                               False
# 499996                               False
# 499997                               False
# 499998                               False
# 499999                               False
#
#         Census_PowerPlatformRoleName_Workstation
# 0                                          False
# 1                                          False
# 2                                          False
# 4                                          False
# 5                                          False
# ...                                          ...
# 499995                                     False
# 499996                                     False
# 499997                                     False
# 499998                                     False
# 499999                                     False
#
# [416972 rows x 97 columns]

# %%
# correlación con el target
df[["Census_InternalBatteryNumberOfCharges", "HasDetections"]].corr()
# Out:
#                                        Census_InternalBatteryNumberOfCharges  \
# Census_InternalBatteryNumberOfCharges                                 1.0000
# HasDetections                                                        -0.0220
#
#                                        HasDetections
# Census_InternalBatteryNumberOfCharges        -0.0220
# HasDetections                                 1.0000

# %%
# es una columna que indirectamente nos puede estar devolviendo en tiempo de uso del dispositivo, proponemos mantenerla aún habiendo 280_000 registros con valor 0 (56%). Es la única que nos proporciona esta información. # TODO: debatir mas a fondo

# %%
del_columns.append("Census_InternalBatteryNumberOfCharges")

# %% [markdown]
# ### "Census_OSVersion"
# Descripción: Versión del sistema operativo

# %%
print(f"{df['Census_OSVersion'].isna().sum()=}")  # 0 nulos
df["Census_OSVersion"].value_counts(dropna=False)
# Únicamente hay un registro con la versión distinta a la 10.0... siendo la 6.3.9600.19069
# Out:
# df['Census_OSVersion'].isna().sum()=0
# Census_OSVersion
# 10.0.17134.228      79211
# 10.0.17134.165      50065
# 10.0.16299.431      30110
# 10.0.17134.285      26034
# 10.0.17134.112      19314
#                     ...
# 10.0.10240.16566        1
# 10.0.15019.1000         1
# 10.0.14328.1000         1
# 10.0.10586.601          1
# 10.0.15048.0            1
# Name: count, Length: 301, dtype: int64

# %%
df[df['OsVer'] == '6.3.0.0'][['OsVer', 'Census_OSVersion']]
# Out:
#           OsVer Census_OSVersion
# 87      6.3.0.0  10.0.14393.1480
# 209     6.3.0.0   10.0.10586.545
# 390     6.3.0.0  10.0.10586.1176
# 404     6.3.0.0   10.0.10586.420
# 456     6.3.0.0    10.0.17134.48
# ...         ...              ...
# 499630  6.3.0.0   10.0.10586.164
# 499640  6.3.0.0   10.0.16299.309
# 499736  6.3.0.0   10.0.10586.420
# 499807  6.3.0.0   10.0.14393.222
# 499851  6.3.0.0   10.0.14393.693
#
# [10554 rows x 2 columns]

# %%
# se podía esperar una fueran la misma columna, pero este ejemplo nos demuestra que no es así
# siendo todos los valores 10.0... podemos prononer a lo sumo quedarnos con "el tercer valor" de la versión que podría estar relacionado con parches de seguridad (p.e.) # TODO: Exponer el caso
# #TODO: Propongo que los valores "muy manipulados" empiecen por CALC_

# evitamos el caso del registro 6.3.9600.19069 eliminándolo
df = df[df['Census_OSVersion'] != '6.3.9600.19069']
df["CALC_Census_OSVersion"] = df["Census_OSVersion"].apply(lambda x: x.split(".")[2])

# %%
# eliminamos la columna original
del_columns.append("Census_OSVersion")

# %%
df["CALC_Census_OSVersion"].value_counts(dropna=False)
# Out:
# CALC_Census_OSVersion
# 17134    223579
# 16299    133412
# 15063     43442
# 14393     42439
# 10586     32442
# 10240     14656
# 17738       162
# 17692       146
# 17744       133
# 17758        97
# 17746        65
# 17763        58
# 17754        56
# 17751        54
# 17741        44
# 17755        40
# 17735        36
# 17686        33
# 17733        31
# 17760        30
# 17133        21
# 17682        18
# 17677        17
# 17672        14
# 18237        14
# 18242        13
# 18234        13
# 17661         9
# 17713         8
# 17666         7
# 17634         4
# 17747         3
# 17639         3
# 17730         2
# 17650         2
# 14986         2
# 17655         2
# 14926         1
# 17749         1
# 14971         1
# 17723         1
# 17623         1
# 16193         1
# 18219         1
# 14295         1
# 17004         1
# 14421         1
# 17604         1
# 17618         1
# 11082         1
# 17046         1
# 14328         1
# 15019         1
# 16251         1
# 14946         1
# 17074         1
# 17753         1
# 15042         1
# 15048         1
# Name: count, dtype: int64

# %% [markdown]
# ### "Census_OSArchitecture"
# Descripción: Arquitectura del sistema operativo

# %%
df["Census_OSArchitecture"].value_counts(dropna=False)  # dos valores únicos (amd64 y x86) y sin nulos
# Out:
# Census_OSArchitecture
# amd64    446175
# x86       44954
# Name: count, dtype: int64

# %%
# comprobamos correlación con la columna processor_x64 y processor_x86
df[df["Processor"] == True]["Census_OSArchitecture"].value_counts()  # coincide en un 446_028/(446_028+452) = 99.9%
# Out:
# Census_OSArchitecture
# x86      44506
# amd64      459
# Name: count, dtype: int64

# %%
df[df["Processor"] == True]["Census_OSArchitecture"].value_counts()  # coincide en un 44555/(44555+459) = 99.9%
# Out:
# Census_OSArchitecture
# x86      44506
# amd64      459
# Name: count, dtype: int64

# %%
# TODO: puesto que esta columna no es nada conlfictiva, tengo que preguntar que tal se comportó la otra columna (processor) preguntar a fran
# eliminamos la columna por ser redundante
del_columns.append("Census_OSArchitecture")

# %% [markdown]
# ### "Census_OSBranch"
# Descripción: Rama del sistema operativo

# %%
df["Census_OSBranch"].value_counts(dropna=False)
# Out:
# Census_OSBranch
# rs4_release                  223601
# rs3_release                   67238
# rs3_release_svc_escrow        65858
# rs2_release                   43444
# rs1_release                   42442
# th2_release                   17856
# th2_release_sec               14586
# th1_st1                       10483
# th1                            4173
# rs5_release                     819
# rs3_release_svc_escrow_im       316
# rs_prerelease                   178
# rs_prerelease_flt               132
# rs5_release_sigma                 3
# Name: count, dtype: int64

# %%
print(f"{df['Census_OSBranch'].isna().sum()=}")  # 0 nulos
# Out:
# df['Census_OSBranch'].isna().sum()=0

# %%
# viendo los valores únicos y su estructura, proponemos quedarnos con las 3 primeras letras de cada valor que parecen contener la información más relevante
df["CALC_Census_OSBranch"] = df["Census_OSBranch"].apply(lambda x: x[:3])

# %%
df["CALC_Census_OSBranch"].value_counts(dropna=False)
# Out:
# CALC_Census_OSBranch
# rs4    223601
# rs3    133412
# rs2     43444
# rs1     42442
# th2     32442
# th1     14656
# rs5       822
# rs_       310
# Name: count, dtype: int64

# %%
# modificamos el valor menos frecuente ("rs_") a "rs"
df["CALC_Census_OSBranch"] = df["CALC_Census_OSBranch"].replace("rs_", "rs")  # TODO: hacer el split por _ DEBERES

# %%
# eliminamos la columna original
del_columns.append("Census_OSBranch")

# %%
df["CALC_Census_OSBranch"].value_counts(dropna=False)
# Out:
# CALC_Census_OSBranch
# rs4    223601
# rs3    133412
# rs2     43444
# rs1     42442
# th2     32442
# th1     14656
# rs5       822
# rs        310
# Name: count, dtype: int64

# %%
# 8 valores únicos de una variable categórica -> OHE
df = pd.get_dummies(df, columns=["CALC_Census_OSBranch"], prefix="CALC_Census_OSBranch")  # TODO

# %% [markdown]
# ### "Census_OSBuildNumber"
# Descripción: Número de compilación del sistema operativo

# %%
print(f"{df['Census_OSBuildNumber'].isna().sum()=}")  # 0 nulos
df["Census_OSBuildNumber"].value_counts(dropna=False)
# Out:
# df['Census_OSBuildNumber'].isna().sum()=0
# Census_OSBuildNumber
# 17134    223579
# 16299    133412
# 15063     43442
# 14393     42439
# 10586     32442
# 10240     14656
# 17738       162
# 17692       146
# 17744       133
# 17758        97
# 17746        65
# 17763        58
# 17754        56
# 17751        54
# 17741        44
# 17755        40
# 17735        36
# 17686        33
# 17733        31
# 17760        30
# 17133        21
# 17682        18
# 17677        17
# 17672        14
# 18237        14
# 18242        13
# 18234        13
# 17661         9
# 17713         8
# 17666         7
# 17634         4
# 17747         3
# 17639         3
# 17730         2
# 17650         2
# 14986         2
# 17655         2
# 14926         1
# 17749         1
# 14971         1
# 17723         1
# 17623         1
# 16193         1
# 18219         1
# 14295         1
# 17004         1
# 14421         1
# 17604         1
# 17618         1
# 11082         1
# 17046         1
# 14328         1
# 15019         1
# 16251         1
# 14946         1
# 17074         1
# 17753         1
# 15042         1
# 15048         1
# Name: count, dtype: int64

# %%
df[['CALC_Census_OSVersion', 'Census_OSBuildNumber']].dtypes
# Out:
# CALC_Census_OSVersion    object
# Census_OSBuildNumber      int64
# dtype: object

# %%
df[['CALC_Census_OSVersion', 'Census_OSBuildNumber']]
# Out:
#        CALC_Census_OSVersion  Census_OSBuildNumber
# 0                      17134                 17134
# 1                      17134                 17134
# 2                      10586                 10586
# 3                      17134                 17134
# 4                      17134                 17134
# ...                      ...                   ...
# 499995                 16299                 16299
# 499996                 16299                 16299
# 499997                 17134                 17134
# 499998                 16299                 16299
# 499999                 17134                 17134
#
# [491129 rows x 2 columns]

# %%
# viendo que la columna préviamente creada "CALC_Census_OSVersion" contiene la misma información que "Census_OSBuildNumber", eliminamos la columna
del_columns.append("CALC_Census_OSVersion") # TODO: pedir al grupo si mantener el código aún sabiendo que es redundante

# %% [markdown]
# ### "Census_OSBuildRevision"
# Descripción: Revisión de la compilación del sistema operativo

# %%
print(f"{df['Census_OSBuildRevision'].isna().sum()=}")  # 0 nulos
df["Census_OSBuildRevision"].value_counts(dropna=False)
# Out:
# df['Census_OSBuildRevision'].isna().sum()=0
# Census_OSBuildRevision
# 228      79211
# 165      50065
# 431      30110
# 285      26034
# 112      19316
#          ...
# 491          1
# 17643        1
# 16389        1
# 2156         1
# 1670         1
# Name: count, Length: 238, dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0                 MachineIdentifier   ProductName EngineVersion  \
# 0     8427007  f1cd864e97bae82bdf96523e1a539121  win8defender   1.1.15100.1
# 1     8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender   1.1.15100.1
#
#         AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 0  4.18.1807.18075  1.273.1234.0       0            7.0000                 0
# 1  4.18.1807.18075  1.273.1282.0       0            7.0000                 0
#
#    DefaultBrowsersIdentifier  ...  Census_PowerPlatformRoleName_Workstation  \
# 0                        NaN  ...                                     False
# 1                        NaN  ...                                     False
#
#    CALC_Census_OSVersion  CALC_Census_OSBranch_rs  CALC_Census_OSBranch_rs1  \
# 0                  17134                    False                     False
# 1                  17134                    False                     False
#
#    CALC_Census_OSBranch_rs2  CALC_Census_OSBranch_rs3  \
# 0                     False                     False
# 1                     False                     False
#
#    CALC_Census_OSBranch_rs4  CALC_Census_OSBranch_rs5  \
# 0                      True                     False
# 1                      True                     False
#
#    CALC_Census_OSBranch_th1  CALC_Census_OSBranch_th2
# 0                     False                     False
# 1                     False                     False
#
# [2 rows x 106 columns]

# %%
# se observa que Census_OSVersion se construye a partir de Census_OSBuildNumber y Census_OSBuildRevision, eliminamos la columna
# proponemos eliminar la columna Census_OSVersion (ya insertada en del_columns) porque es un str y las otras dos columnas son numéricas

# %%
del_columns.append("Census_OSBuildRevision")

# %% [markdown]
# ### "Census_OSEdition"
# Descripción: Edición del sistema operativo

# %%
print(f"{df['Census_OSEdition'].isna().sum()=}")  # 0 nulos
df["Census_OSEdition"].value_counts(dropna=False)
# Out:
# df['Census_OSEdition'].isna().sum()=0
# Census_OSEdition
# Core                        192290
# Professional                171597
# CoreSingleLanguage          107431
# CoreCountrySpecific           9150
# ProfessionalEducation         3071
# Education                     2262
# Enterprise                    1987
# ProfessionalN                 1553
# EnterpriseS                   1072
# Cloud                          326
# CoreN                          240
# EducationN                      60
# EnterpriseSN                    45
# EnterpriseN                     27
# ProfessionalEducationN          12
# ServerStandard                   2
# ProfessionalWorkstation          2
# CloudN                           1
# ProfessionalWorkstationN         1
# Name: count, dtype: int64

# %%
# hay 3 valores muy predominantes con 192000, 171000 y 107000 registros respectivamente (38.9%, 34.7% y 21.7%). Se propone agrupar los 16 valores restantes en un solo valor "Otro" y posteriormente hacer un OHE
# agrupamos los valores menos frecuentes
df["Census_OSEdition"] = df["Census_OSEdition"].replace(df["Census_OSEdition"].value_counts().index[3:], "Otro")

# %%
df["Census_OSEdition"].value_counts(dropna=False)
# Out:
# Census_OSEdition
# Core                  192290
# Professional          171597
# CoreSingleLanguage    107431
# Otro                   19811
# Name: count, dtype: int64

# %%
# la columna otros contiene 19827 registros (4%)
# OHE
df = pd.get_dummies(df, columns=["Census_OSEdition"], prefix="Census_OSEdition")  # TODO

# %% [markdown]
# ### "Census_OSSkuName"
# Descripción: Nombre de la versión del sistema operativo

# %%
print(f"{df['Census_OSSkuName'].isna().sum()=}")  # 0 nulos
df["Census_OSSkuName"].value_counts(dropna=False)
# Out:
# df['Census_OSSkuName'].isna().sum()=0
# Census_OSSkuName
# CORE                    192285
# PROFESSIONAL            174705
# CORE_SINGLELANGUAGE     107409
# CORE_COUNTRYSPECIFIC      9133
# EDUCATION                 2265
# ENTERPRISE                1996
# PROFESSIONAL_N            1563
# ENTERPRISE_S              1071
# CLOUD                      322
# CORE_N                     240
# EDUCATION_N                 60
# ENTERPRISE_S_N              46
# ENTERPRISE_N                27
# STANDARD_SERVER              2
# PRO_WORKSTATION              2
# CLOUDN                       1
# PRO_WORKSTATION_N            1
# UNLICENSED                   1
# Name: count, dtype: int64

# %%
# es un atributo prácticamente idéntico a Census_OSEdition, eliminamos la columna
del_columns.append("Census_OSSkuName")

# %% [markdown]
# ### "Census_OSInstallTypeName"
# Descripción: Método de instalación del sistema operativo

# %%
print(f"{df['Census_OSInstallTypeName'].isna().sum()=}")  # 0 nulos
df["Census_OSInstallTypeName"].value_counts(dropna=False)
# Out:
# df['Census_OSInstallTypeName'].isna().sum()=0
# Census_OSInstallTypeName
# UUPUpgrade        145648
# IBSClean           88462
# Update             87884
# Upgrade            69228
# Other              46079
# Reset              35985
# Refresh            11109
# Clean               3842
# CleanPCRefresh      2892
# Name: count, dtype: int64

# %%
# puede parecer difícilmente relacionable con el target, comprobamos correlaciones
df_dummies = pd.get_dummies(df['Census_OSInstallTypeName'], prefix='Census_OSInstallTypeName')
correlations = df_dummies.corrwith(df['HasDetections'])
correlations
# Out:
# Census_OSInstallTypeName_Clean             0.0037
# Census_OSInstallTypeName_CleanPCRefresh   -0.0057
# Census_OSInstallTypeName_IBSClean          0.0231
# Census_OSInstallTypeName_Other            -0.0152
# Census_OSInstallTypeName_Refresh          -0.0113
# Census_OSInstallTypeName_Reset            -0.0105
# Census_OSInstallTypeName_UUPUpgrade        0.0332
# Census_OSInstallTypeName_Update           -0.0209
# Census_OSInstallTypeName_Upgrade          -0.0204
# dtype: float64

# %%
# correlaciones no superiores al 0.04 -> eliminamos la columna
del_columns.append("Census_OSInstallTypeName")

# %%
df['Census_FirmwareManufacturerIdentifier'].value_counts().sort_values(ascending=False).index[:6].to_list()
# Out:
# [142.0, 628.0, 554.0, 355.0, 556.0, 500.0]

# %%
df['Census_FirmwareVersionIdentifier'].value_counts().sort_values(ascending=False)
# Out:
# Census_FirmwareVersionIdentifier
# 33105.0000    5017
# 33111.0000    3338
# 33054.0000    3109
# 33108.0000    3048
# 63175.0000    2953
#               ...
# 16331.0000       1
# 48387.0000       1
# 68817.0000       1
# 49471.0000       1
# 54497.0000       1
# Name: count, Length: 23350, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491129 entries, 0 to 499999
# Columns: 109 entries, Unnamed: 0 to Census_OSEdition_Professional
# dtypes: bool(24), float64(37), int64(19), object(29)
# memory usage: 333.5+ MB

# %% [markdown]
# ## Parte IGNACIO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491129 entries, 0 to 499999
# Columns: 109 entries, Unnamed: 0 to Census_OSEdition_Professional
# dtypes: bool(24), float64(37), int64(19), object(29)
# memory usage: 333.5+ MB

# %%
valores_faltantes = (df.isnull().mean() * 100).sort_values(ascending=False)
print(valores_faltantes)
# Out:
# PuaMode                         99.9752
# Census_ProcessorClass           99.5856
# DefaultBrowsersIdentifier       95.2273
# Census_IsFlightingInternal      82.9827
# Census_InternalBatteryType      70.9526
#                                   ...
# Census_TotalPhysicalRAM          0.0000
# Census_HasOpticalDiskDrive       0.0000
# Census_DeviceFamily              0.0000
# Census_MDC2FormFactor            0.0000
# Census_OSEdition_Professional    0.0000
# Length: 109, dtype: float64

# %%
((df.isna().sum()/df.shape[0])*100).sort_values().plot(kind="barh",figsize=(10,10),color="lightblue")
plt.title('Porcentaje de valores faltantes')
plt.xlabel('Porcentaje del total de filas')
plt.ylabel('Variable')
plt.xlim(0, 100)
plt.show()

# %%
df = df.drop(columns=['PuaMode', 'SMode', 'SmartScreen', 'OsBuild', 'OsPlatformSubRelease', 'OsBuildLab', 'AutoSampleOptIn', 'Census_MDC2FormFactor', 'Census_DeviceFamily', 'Census_OEMModelIdentifier'])

# %%
columnas_objetivo_ict = ['Census_OEMNameIdentifier','Firewall','IeVerIdentifier','Census_ProcessorModelIdentifier','Census_ProcessorCoreCount','Census_ProcessorManufacturerIdentifier','IsProtected','UacLuaenable']
df = df.dropna(subset=columnas_objetivo_ict)

df = df[~df["UacLuaenable"].isin(list([48.0, 6357062.0000, 2.0]))]
df = df[df['Census_ProcessorManufacturerIdentifier'] != 3.0]

# %%
df["OsVer"].value_counts()
# Out:
# OsVer
# 10.0.0.0      466793
# 6.3.0.0        10410
# 6.1.1.0          795
# 10.0.3.0          11
# 10.0.1.0           7
# 6.1.0.0            3
# 6.3.3.0            2
# 10.0.0.1           2
# 6.3.1.0            2
# 10.0.32.72         2
# 10.0.32.0          1
# 10.0.80.0          1
# 10.0.5.0           1
# 10.0.2.0           1
# 6.3.5.0            1
# 10.0.4.0           1
# 10.0.8.0           1
# 10.0.0.112         1
# 6.3.32.72          1
# 6.3.7.0            1
# 10.0.7.0           1
# Name: count, dtype: int64

# %%
df['OsVer'] = df['OsVer'].apply(lambda x: x.split('.')[0])

# %%
df['OsSuite'].value_counts()
# Out:
# OsSuite
# 768    301672
# 256    176356
# 784        10
# Name: count, dtype: int64

# %%
df = df[df['OsSuite'] != 784]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478028 entries, 0 to 499999
# Data columns (total 99 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Unnamed: 0                                         478028 non-null  int64
#  1   MachineIdentifier                                  478028 non-null  object
#  2   ProductName                                        478028 non-null  object
#  3   EngineVersion                                      478028 non-null  object
#  4   AppVersion                                         478028 non-null  object
#  5   AvSigVersion                                       478028 non-null  object
#  6   IsBeta                                             478028 non-null  int64
#  7   RtpStateBitfield                                   476304 non-null  float64
#  8   IsSxsPassiveMode                                   478028 non-null  int64
#  9   DefaultBrowsersIdentifier                          23036 non-null   float64
#  10  AVProductStatesIdentifier                          478028 non-null  float64
#  11  AVProductsInstalled                                478028 non-null  float64
#  12  AVProductsEnabled                                  478028 non-null  float64
#  13  HasTpm                                             478028 non-null  int64
#  14  CountryIdentifier                                  478028 non-null  int64
#  15  CityIdentifier                                     460498 non-null  float64
#  16  OrganizationIdentifier                             330234 non-null  float64
#  17  GeoNameIdentifier                                  478015 non-null  float64
#  18  LocaleEnglishNameIdentifier                        478028 non-null  int64
#  19  Processor                                          478028 non-null  int64
#  20  OsVer                                              478028 non-null  object
#  21  OsSuite                                            478028 non-null  int64
#  22  SkuEdition                                         478028 non-null  object
#  23  IsProtected                                        478028 non-null  float64
#  24  IeVerIdentifier                                    478028 non-null  float64
#  25  Firewall                                           478028 non-null  float64
#  26  UacLuaenable                                       478028 non-null  float64
#  27  Census_OEMNameIdentifier                           478028 non-null  float64
#  28  Census_ProcessorCoreCount                          478028 non-null  float64
#  29  Census_ProcessorManufacturerIdentifier             478028 non-null  float64
#  30  Census_ProcessorModelIdentifier                    478028 non-null  float64
#  31  Census_ProcessorClass                              1664 non-null    object
#  32  Census_PrimaryDiskTotalCapacity                    477803 non-null  float64
#  33  Census_SystemVolumeTotalCapacity                   477803 non-null  float64
#  34  Census_HasOpticalDiskDrive                         478028 non-null  int64
#  35  Census_TotalPhysicalRAM                            478028 non-null  float64
#  36  Census_ChassisTypeName                             478016 non-null  object
#  37  Census_InternalPrimaryDiagonalDisplaySizeInInches  475838 non-null  float64
#  38  Census_InternalPrimaryDisplayResolutionHorizontal  475842 non-null  float64
#  39  Census_InternalPrimaryDisplayResolutionVertical    475842 non-null  float64
#  40  Census_InternalBatteryType                         138846 non-null  object
#  41  Census_InternalBatteryNumberOfCharges              478028 non-null  float64
#  42  Census_OSVersion                                   478028 non-null  object
#  43  Census_OSArchitecture                              478028 non-null  object
#  44  Census_OSBranch                                    478028 non-null  object
#  45  Census_OSBuildNumber                               478028 non-null  int64
#  46  Census_OSBuildRevision                             478028 non-null  int64
#  47  Census_OSSkuName                                   478028 non-null  object
#  48  Census_OSInstallTypeName                           478028 non-null  object
#  49  Census_OSInstallLanguageIdentifier                 475057 non-null  float64
#  50  Census_OSUILocaleIdentifier                        478028 non-null  int64
#  51  Census_OSWUAutoUpdateOptionsName                   478028 non-null  object
#  52  Census_IsPortableOperatingSystem                   478028 non-null  int64
#  53  Census_GenuineStateName                            478028 non-null  object
#  54  Census_ActivationChannel                           478028 non-null  object
#  55  Census_IsFlightingInternal                         80879 non-null   float64
#  56  Census_IsFlightsDisabled                           473923 non-null  float64
#  57  Census_FlightRing                                  478028 non-null  object
#  58  Census_ThresholdOptIn                              173407 non-null  float64
#  59  Census_FirmwareManufacturerIdentifier              473522 non-null  float64
#  60  Census_FirmwareVersionIdentifier                   474799 non-null  float64
#  61  Census_IsSecureBootEnabled                         478028 non-null  int64
#  62  Census_IsWIMBootEnabled                            173823 non-null  float64
#  63  Census_IsVirtualDevice                             477169 non-null  float64
#  64  Census_IsTouchEnabled                              478028 non-null  int64
#  65  Census_IsPenCapable                                478028 non-null  int64
#  66  Census_IsAlwaysOnAlwaysConnectedCapable            476831 non-null  float64
#  67  Wdft_IsGamer                                       462020 non-null  float64
#  68  Wdft_RegionIdentifier                              462020 non-null  float64
#  69  HasDetections                                      478028 non-null  int64
#  70  EngineVersion_trimmed                              478028 non-null  object
#  71  AppVersion_trimmed                                 478028 non-null  object
#  72  AvSigVersion_trimmed                               478028 non-null  object
#  73  Platform_windows10                                 478028 non-null  bool
#  74  Platform_windows7                                  478028 non-null  bool
#  75  Platform_windows8                                  478028 non-null  bool
#  76  Census_PrimaryDiskTypeName_HDD                     478028 non-null  bool
#  77  Census_PrimaryDiskTypeName_Indefinido              478028 non-null  bool
#  78  Census_PrimaryDiskTypeName_SSD                     478028 non-null  bool
#  79  Census_TotalPhysicalRAM_GB                         478028 non-null  float64
#  80  Census_PowerPlatformRoleName_AppliancePC           478028 non-null  bool
#  81  Census_PowerPlatformRoleName_Desktop               478028 non-null  bool
#  82  Census_PowerPlatformRoleName_Mobile                478028 non-null  bool
#  83  Census_PowerPlatformRoleName_Server                478028 non-null  bool
#  84  Census_PowerPlatformRoleName_Slate                 478028 non-null  bool
#  85  Census_PowerPlatformRoleName_Workstation           478028 non-null  bool
#  86  CALC_Census_OSVersion                              478028 non-null  object
#  87  CALC_Census_OSBranch_rs                            478028 non-null  bool
#  88  CALC_Census_OSBranch_rs1                           478028 non-null  bool
#  89  CALC_Census_OSBranch_rs2                           478028 non-null  bool
#  90  CALC_Census_OSBranch_rs3                           478028 non-null  bool
#  91  CALC_Census_OSBranch_rs4                           478028 non-null  bool
#  92  CALC_Census_OSBranch_rs5                           478028 non-null  bool
#  93  CALC_Census_OSBranch_th1                           478028 non-null  bool
#  94  CALC_Census_OSBranch_th2                           478028 non-null  bool
#  95  Census_OSEdition_Core                              478028 non-null  bool
#  96  Census_OSEdition_CoreSingleLanguage                478028 non-null  bool
#  97  Census_OSEdition_Otro                              478028 non-null  bool
#  98  Census_OSEdition_Professional                      478028 non-null  bool
# dtypes: bool(24), float64(35), int64(17), object(23)
# memory usage: 288.1+ MB

# %% [markdown]
# ## Parte ALVARO

# %%
df[alvaro_columns].isna().sum()
# Out:
# Census_OSInstallLanguageIdentifier           2971
# Census_OSUILocaleIdentifier                     0
# Census_OSWUAutoUpdateOptionsName                0
# Census_IsPortableOperatingSystem                0
# Census_GenuineStateName                         0
# Census_ActivationChannel                        0
# Census_IsFlightingInternal                 397149
# Census_IsFlightsDisabled                     4105
# Census_FlightRing                               0
# Census_ThresholdOptIn                      304621
# Census_FirmwareManufacturerIdentifier        4506
# Census_FirmwareVersionIdentifier             3229
# Census_IsSecureBootEnabled                      0
# Census_IsWIMBootEnabled                    304205
# Census_IsVirtualDevice                        859
# Census_IsTouchEnabled                           0
# Census_IsPenCapable                             0
# Census_IsAlwaysOnAlwaysConnectedCapable      1197
# Wdft_IsGamer                                16008
# Wdft_RegionIdentifier                       16008
# HasDetections                                   0
# dtype: int64

# %% [markdown]
# ---
# ### Census_IsFlightingInternal, Census_ThresholdOptIn y Census_IsWIMBootEnabled.

# %% [markdown]
# ##### Primero quiero visualizar el porcentaje de valores nulos por columna

# %%
(df[alvaro_columns].isnull().sum() / len(df[alvaro_columns])) * 100
# Out:
# Census_OSInstallLanguageIdentifier         0.6215
# Census_OSUILocaleIdentifier                0.0000
# Census_OSWUAutoUpdateOptionsName           0.0000
# Census_IsPortableOperatingSystem           0.0000
# Census_GenuineStateName                    0.0000
# Census_ActivationChannel                   0.0000
# Census_IsFlightingInternal                83.0807
# Census_IsFlightsDisabled                   0.8587
# Census_FlightRing                          0.0000
# Census_ThresholdOptIn                     63.7245
# Census_FirmwareManufacturerIdentifier      0.9426
# Census_FirmwareVersionIdentifier           0.6755
# Census_IsSecureBootEnabled                 0.0000
# Census_IsWIMBootEnabled                   63.6375
# Census_IsVirtualDevice                     0.1797
# Census_IsTouchEnabled                      0.0000
# Census_IsPenCapable                        0.0000
# Census_IsAlwaysOnAlwaysConnectedCapable    0.2504
# Wdft_IsGamer                               3.3488
# Wdft_RegionIdentifier                      3.3488
# HasDetections                              0.0000
# dtype: float64

# %% [markdown]
# #####  Lo primero que estoy viendo es que hay columnas con un 50% de nulos, estas son `Census_IsFlightingInternal`, `Census_ThresholdOptIn` y `Census_IsWIMBootEnabled`.
# #####  Por lo tanto voy a proceder a prescindir de estas.

# %%
del_columns.extend(["Census_IsFlightingInternal", "Census_ThresholdOptIn", "Census_IsWIMBootEnabled"])

# %% [markdown]
# ---
# ### Census_OSInstallLanguageIdentifier

# %%
df["Census_OSInstallLanguageIdentifier"].value_counts()
# Out:
# Census_OSInstallLanguageIdentifier
# 8.0000     170808
# 9.0000      55385
# 7.0000      27834
# 29.0000     26176
# 14.0000     23089
# 37.0000     21506
# 10.0000     19746
# 26.0000     17468
# 5.0000      13302
# 35.0000     11031
# 39.0000     10753
# 18.0000     10065
# 20.0000      9180
# 24.0000      7751
# 25.0000      7156
# 27.0000      5776
# 19.0000      4507
# 17.0000      4496
# 1.0000       4379
# 3.0000       3874
# 6.0000       2765
# 33.0000      2693
# 15.0000      2205
# 4.0000       1925
# 30.0000      1726
# 23.0000      1581
# 31.0000      1171
# 12.0000      1073
# 2.0000       1053
# 16.0000       817
# 36.0000       814
# 28.0000       688
# 34.0000       562
# 13.0000       554
# 21.0000       389
# 32.0000       236
# 11.0000       186
# 38.0000       169
# 22.0000       168
# Name: count, dtype: int64

# %% [markdown]
# Vamos a ver que grado de correlacion tiene con el target y asi saber si podemos descartarla con seguridad.

# %%
df[["Census_OSInstallLanguageIdentifier", "HasDetections"]].corr()
# Out:
#                                     Census_OSInstallLanguageIdentifier  \
# Census_OSInstallLanguageIdentifier                              1.0000
# HasDetections                                                   0.0035
#
#                                     HasDetections
# Census_OSInstallLanguageIdentifier         0.0035
# HasDetections                              1.0000

# %% [markdown]
# ##### Podemos ver que la correlacion es de menos de un 0.001%, por lo tanto es seguro descartarla.

# %%
del_columns.append('Census_OSInstallLanguageIdentifier')

# %% [markdown]
# ---
# ### Census_OSUILocaleIdentifier

# %%
df["Census_OSUILocaleIdentifier"].value_counts()
# Out:
# Census_OSUILocaleIdentifier
# 31     170306
# 34      55648
# 30      27863
# 125     26485
# 49      23299
#         ...
# 89          1
# 22          1
# 6           1
# 71          1
# 141         1
# Name: count, Length: 89, dtype: int64

# %% [markdown]
# En base de la correlacion que mantenga con el target, decidiremos si prescindimos de esta columna o no.

# %%
df[["Census_OSUILocaleIdentifier", "HasDetections"]].corr()
# Out:
#                              Census_OSUILocaleIdentifier  HasDetections
# Census_OSUILocaleIdentifier                       1.0000         0.0026
# HasDetections                                     0.0026         1.0000

# %% [markdown]
# ##### Al igual que con la anterior columna, no llega ni al 1% de correlacion, por lo tanto vamos a eliminar esta columna.

# %%
del_columns.append('Census_OSUILocaleIdentifier')

# %% [markdown]
# ---
# ### Census_OSWUAutoUpdateOptionsName

# %%
df["Census_OSWUAutoUpdateOptionsName"].value_counts()
# Out:
# Census_OSWUAutoUpdateOptionsName
# FullAuto                                 211736
# UNKNOWN                                  134676
# Notify                                   110133
# AutoInstallAndRebootAtMaintenanceTime     20086
# Off                                        1397
# Name: count, dtype: int64

# %% [markdown]
# Esta columna tiene mas sentido mantenerla por que no tiene muchos valores y tiene mas sentido que algo relacionado con actualizaciones del OS tenga relacion con el target. A pesar de que tenemos aproximadamente un 25% de valores con `UNKNOWN` veremos que pasa en los tests y en funcion de eso volveremos para eliminarla o no.

# %% [markdown]
# ---
# ### Census_IsPortableOperatingSystem

# %%
df["Census_IsPortableOperatingSystem"].value_counts()
# Out:
# Census_IsPortableOperatingSystem
# 0    477788
# 1       240
# Name: count, dtype: int64

# %% [markdown]
# ##### Esta columna ademas de no tener nulos (como hemos visto anteriormente) solo contiene 0 y 1.

# %%
df[["Census_IsPortableOperatingSystem", "HasDetections"]].corr()
# Out:
#                                   Census_IsPortableOperatingSystem  \
# Census_IsPortableOperatingSystem                            1.0000
# HasDetections                                               0.0007
#
#                                   HasDetections
# Census_IsPortableOperatingSystem         0.0007
# HasDetections                            1.0000

# %% [markdown]
# Lo unico que no me convence es que la correlacion es muy baja. Eliminaremos esta columna ya que no afectara mucho al entrenamiendo del modelo.

# %%
del_columns.append('Census_IsPortableOperatingSystem')

# %% [markdown]
# ---
# ### Census_GenuineStateName

# %% [markdown]
# Borraremos las obeservaciones que tenga valor `UNKNOWN` ya que asi nos ahorraremos una columna categorica.

# %%
df[~df["Census_GenuineStateName"].isin(["UNKNOWN"])]["Census_GenuineStateName"].value_counts()
# Out:
# Census_GenuineStateName
# IS_GENUINE         423216
# INVALID_LICENSE     42228
# OFFLINE             12211
# Name: count, dtype: int64

# %% [markdown]
# Aunque los valores estan desbalanceados, haremos pruebas y según los resultados de estas veremos si mantener o no la columna
#
# El siguiente punto será hacer un OHE con esta columna

# %%
df = df[df["Census_GenuineStateName"] != "UNKNOWN"]

# %% [markdown]
# ---
# ### Census_ActivationChannel

# %%
df["Census_ActivationChannel"].value_counts()
# Out:
# Census_ActivationChannel
# Retail         248816
# OEM:DM         187662
# Volume:GVLK     23630
# OEM:NONSLP      17106
# Volume:MAK        441
# Name: count, dtype: int64

# %%
df["Census_ActivationChannel"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Podemos ver que hay dos valores que predominan. Podriamos prescindir de las pocas observaciones con valores `Volume:MAK` y `Retail:TB:Eval` para asi tener dos columnas catergoricas menos al hacer OHE

# %%
df[~df["Census_ActivationChannel"].isin(["Volume:MAK", "Retail:TB:Eval"])]["Census_ActivationChannel"].value_counts()
# Out:
# Census_ActivationChannel
# Retail         248816
# OEM:DM         187662
# Volume:GVLK     23630
# OEM:NONSLP      17106
# Name: count, dtype: int64

# %% [markdown]
# ---
# ### Census_IsFlightsDisabled

# %%
df["Census_IsFlightsDisabled"].value_counts()
# Out:
# Census_IsFlightsDisabled
# 0.0000    473546
# 1.0000         7
# Name: count, dtype: int64

# %%
df[["Census_IsFlightsDisabled", "HasDetections"]].corr()
# Out:
#                           Census_IsFlightsDisabled  HasDetections
# Census_IsFlightsDisabled                    1.0000        -0.0039
# HasDetections                              -0.0039         1.0000

# %% [markdown]
# A parte de que la varianza es casi inexistente, la correlacion es tambien muy baja, por lo tanto eliminaremos esta columna.

# %%
del_columns.append('Census_IsFlightsDisabled')

# %% [markdown]
# ---
# ### Census_FlightRing

# %%
df["Census_FlightRing"].value_counts()
# Out:
# Census_FlightRing
# Retail      447406
# NOT_SET      15264
# Unknown      13154
# WIS            571
# RP             552
# WIF            509
# Disabled       198
# OSG              1
# Name: count, dtype: int64

# %%
df["Census_FlightRing"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Aqui podemos apreciar valores muy desbalanceados y como poca variabilidad. Vamos a eliminar esta columna.

# %%
del_columns.append('Census_FlightRing')

# %% [markdown]
# ---
# ### Census_FirmwareManufacturerIdentifier

# %%
df["Census_FirmwareManufacturerIdentifier"].value_counts().sort_index()
# Out:
# Census_FirmwareManufacturerIdentifier
# 11.0000        3
# 13.0000        1
# 17.0000        2
# 33.0000        1
# 34.0000        1
#             ...
# 1075.0000    264
# 1079.0000     10
# 1080.0000     54
# 1081.0000     11
# 1083.0000      8
# Name: count, Length: 290, dtype: int64

# %%
df["Census_FirmwareManufacturerIdentifier"].value_counts().sort_values(ascending=False)
# Out:
# Census_FirmwareManufacturerIdentifier
# 142.0000    146794
# 628.0000     67231
# 554.0000     64642
# 355.0000     51272
# 556.0000     43974
#              ...
# 626.0000         1
# 574.0000         1
# 423.0000         1
# 709.0000         1
# 585.0000         1
# Name: count, Length: 290, dtype: int64

# %%
df["Census_FirmwareManufacturerIdentifier"].hist()
# Out:
# <Axes: >

# %%
# Obtener las seis categorías más frecuentes
top_6_categories = df["Census_FirmwareManufacturerIdentifier"].value_counts().nlargest(6).index

# Renombrar las categorías y agrupar las restantes bajo "Otros"
df["Census_FirmwareManufacturerIdentifier"] = df["Census_FirmwareManufacturerIdentifier"].apply(
    lambda x: f"Id_{x}" if x in top_6_categories else "Otros"
)

# Realizar One-Hot Encoding
df = pd.get_dummies(df, columns=["Census_FirmwareManufacturerIdentifier"], prefix="FirmwareManufacturer", prefix_sep="")

# %%
df[[
    'FirmwareManufacturerOtros',
    'FirmwareManufacturerId_142.0',
    'FirmwareManufacturerId_355.0',
    'FirmwareManufacturerId_500.0',
    'FirmwareManufacturerId_554.0',
    'FirmwareManufacturerId_556.0',
    'FirmwareManufacturerId_628.0']].corrwith(df['HasDetections'])
# Out:
# FirmwareManufacturerOtros      -0.0358
# FirmwareManufacturerId_142.0    0.0242
# FirmwareManufacturerId_355.0    0.0070
# FirmwareManufacturerId_500.0   -0.0136
# FirmwareManufacturerId_554.0    0.0076
# FirmwareManufacturerId_556.0    0.0025
# FirmwareManufacturerId_628.0   -0.0009
# dtype: float64

# %%
corr, p_value = pointbiserialr(df['FirmwareManufacturerId_142.0'], df['HasDetections'])
print(f'Correlación: {corr}, p-valor: {p_value}')
# Out:
# Correlación: 0.024170711259291315, p-valor: 1.157719678223397e-62

# %% [markdown]
# Al final hemos decidido mantener la columna como un ID y veremos cuanto ayuda al modelo.

# %% [markdown]
# ---
# ### Census_FirmwareVersionIdentifier

# %%
df["Census_FirmwareVersionIdentifier"].value_counts().sort_index()
# Out:
# Census_FirmwareVersionIdentifier
# 10.0000       1
# 23.0000       1
# 33.0000       1
# 37.0000       1
# 38.0000       2
#              ..
# 72077.0000    4
# 72079.0000    1
# 72080.0000    2
# 72087.0000    1
# 72089.0000    1
# Name: count, Length: 22703, dtype: int64

# %%
df["Census_FirmwareVersionIdentifier"].value_counts().sort_values(ascending=False)
# Out:
# Census_FirmwareVersionIdentifier
# 33105.0000    4983
# 33111.0000    3297
# 33054.0000    3089
# 33108.0000    3017
# 63175.0000    2903
#               ...
# 17783.0000       1
# 36818.0000       1
# 12215.0000       1
# 3490.0000        1
# 54497.0000       1
# Name: count, Length: 22703, dtype: int64

# %%
df["Census_FirmwareVersionIdentifier"].hist()
# Out:
# <Axes: >

# %%
df["Census_FirmwareVersionIdentifier"].nunique()
# Out:
# 22703

# %%
df[["Census_FirmwareVersionIdentifier", "HasDetections"]].corr()
# Out:
#                                   Census_FirmwareVersionIdentifier  \
# Census_FirmwareVersionIdentifier                            1.0000
# HasDetections                                               0.0012
#
#                                   HasDetections
# Census_FirmwareVersionIdentifier         0.0012
# HasDetections                            1.0000

# %% [markdown]
# Una vez mas, tiene poca correlacion. Prescindimos de ella.

# %%
del_columns.append('Census_FirmwareVersionIdentifier')

# %% [markdown]
# ---
# ### Census_IsSecureBootEnabled

# %%
df["Census_IsSecureBootEnabled"].value_counts().sort_index()
# Out:
# Census_IsSecureBootEnabled
# 0    239808
# 1    237847
# Name: count, dtype: int64

# %%
df[["Census_IsSecureBootEnabled", "HasDetections"]].corr()
# Out:
#                             Census_IsSecureBootEnabled  HasDetections
# Census_IsSecureBootEnabled                      1.0000        -0.0040
# HasDetections                                  -0.0040         1.0000

# %%
df["Census_IsSecureBootEnabled"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Aqui podemos ver que la relacion con el target es muy baja. Eliminaremos esta columna.

# %%
del_columns.append('Census_IsSecureBootEnabled')

# %% [markdown]
# ---
# ### Census_IsVirtualDevice

# %%
df["Census_IsVirtualDevice"].value_counts().sort_index()
# Out:
# Census_IsVirtualDevice
# 0.0000    474885
# 1.0000      1911
# Name: count, dtype: int64

# %%
df["Census_IsVirtualDevice"].hist()
# Out:
# <Axes: >

# %%
df[["Census_IsVirtualDevice", "HasDetections"]].corr()
# Out:
#                         Census_IsVirtualDevice  HasDetections
# Census_IsVirtualDevice                  1.0000        -0.0394
# HasDetections                          -0.0394         1.0000

# %% [markdown]
# Siendo la correlacion tan baja y el balance de datos tan descompensado tambien vamos a eliminar esta columna.

# %%
del_columns.append('Census_IsVirtualDevice')

# %% [markdown]
# ---
# ### Census_IsTouchEnabled

# %%
df["Census_IsTouchEnabled"].value_counts().sort_index()
# Out:
# Census_IsTouchEnabled
# 0    416380
# 1     61275
# Name: count, dtype: int64

# %%
df["Census_IsTouchEnabled"].hist()
# Out:
# <Axes: >

# %%
df[["Census_IsTouchEnabled", "HasDetections"]].corr()
# Out:
#                        Census_IsTouchEnabled  HasDetections
# Census_IsTouchEnabled                 1.0000        -0.0414
# HasDetections                        -0.0414         1.0000

# %% [markdown]
# No hay mucha correlacion con el target y los valores estan descompensados. Eliminamos la columna.

# %%
del_columns.append('Census_IsTouchEnabled')

# %% [markdown]
# ---
# ### Census_IsPenCapable

# %%
df["Census_IsPenCapable"].value_counts().sort_index()
# Out:
# Census_IsPenCapable
# 0    459287
# 1     18368
# Name: count, dtype: int64

# %%
df["Census_IsPenCapable"].hist()
# Out:
# <Axes: >

# %%
df[["Census_IsPenCapable", "HasDetections"]].corr()
# Out:
#                      Census_IsPenCapable  HasDetections
# Census_IsPenCapable               1.0000        -0.0176
# HasDetections                    -0.0176         1.0000

# %% [markdown]
# No hay mucha correlacion con el target y los valores estan descompensados. Eliminamos la columna.

# %%
del_columns.append('Census_IsPenCapable')

# %% [markdown]
# ---
# ### Census_IsAlwaysOnAlwaysConnectedCapable

# %%
df["Census_IsAlwaysOnAlwaysConnectedCapable"].value_counts().sort_index()
# Out:
# Census_IsAlwaysOnAlwaysConnectedCapable
# 0.0000    448401
# 1.0000     28062
# Name: count, dtype: int64

# %%
df["Census_IsAlwaysOnAlwaysConnectedCapable"].hist()
# Out:
# <Axes: >

# %%
df[["Census_IsAlwaysOnAlwaysConnectedCapable", "HasDetections"]].corr()
# Out:
#                                          Census_IsAlwaysOnAlwaysConnectedCapable  \
# Census_IsAlwaysOnAlwaysConnectedCapable                                   1.0000
# HasDetections                                                            -0.0643
#
#                                          HasDetections
# Census_IsAlwaysOnAlwaysConnectedCapable        -0.0643
# HasDetections                                   1.0000

# %% [markdown]
# No hay mucha correlacion con el target y los valores estan descompensados. Eliminamos la columna.

# %%
del_columns.append('Census_IsAlwaysOnAlwaysConnectedCapable')

# %% [markdown]
# ---
# ### Wdft_IsGamer

# %%
df["Wdft_IsGamer"].value_counts().sort_index()
# Out:
# Wdft_IsGamer
# 0.0000    328635
# 1.0000    133032
# Name: count, dtype: int64

# %%
df["Wdft_IsGamer"].hist()
# Out:
# <Axes: >

# %%
df[["Wdft_IsGamer", "HasDetections"]].corr()
# Out:
#                Wdft_IsGamer  HasDetections
# Wdft_IsGamer         1.0000         0.0568
# HasDetections        0.0568         1.0000

# %% [markdown]
# No hay mucha correlacion con el target y los valores estan descompensados. Eliminamos la columna.

# %%
del_columns.append('Wdft_IsGamer')

# %% [markdown]
# ---
# ### Wdft_RegionIdentifier

# %%
df["Wdft_RegionIdentifier"].value_counts().sort_index()
# Out:
# Wdft_RegionIdentifier
# 1.0000     66322
# 2.0000      4223
# 3.0000     69545
# 4.0000      7065
# 5.0000     10753
# 6.0000      8182
# 7.0000     31700
# 8.0000     15091
# 9.0000      4248
# 10.0000    96313
# 11.0000    73024
# 12.0000     8617
# 13.0000    11797
# 14.0000      211
# 15.0000    54576
# Name: count, dtype: int64

# %%
# Calcular el umbral del 5%
threshold = len(df) * 0.05

# Obtener los valores que superan el umbral
top_region_ids = df["Wdft_RegionIdentifier"].value_counts()[df["Wdft_RegionIdentifier"].value_counts() > threshold].index

# Renombrar las categorías y agrupar las restantes bajo "OtrosRegionId"
df["Wdft_RegionIdentifier"] = df["Wdft_RegionIdentifier"].apply(
    lambda x: f"RegionId_{x}" if x in top_region_ids else "OtrosRegionId"
)

# Realizar One-Hot Encoding
df = pd.get_dummies(df, columns=["Wdft_RegionIdentifier"], prefix="", prefix_sep="")

# %%
df.head()
# Out:
#    Unnamed: 0                 MachineIdentifier   ProductName EngineVersion  \
# 0     8427007  f1cd864e97bae82bdf96523e1a539121  win8defender   1.1.15100.1
# 1     8829090  fd5ba6f5b75325ec0423a6c67cc75942  win8defender   1.1.15100.1
# 2     2731904  4e628391e7cc7c482fb3286f486dbd25  win8defender   1.1.15100.1
# 3     1359513  270a2e9d028144a4df12a9e3da79fba5  win8defender   1.1.15200.1
# 4      236059  06ca8fa8d32c2abdc5b3577d676b3269  win8defender   1.1.15200.1
#
#         AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 0  4.18.1807.18075  1.273.1234.0       0            7.0000                 0
# 1  4.18.1807.18075  1.273.1282.0       0            7.0000                 0
# 2   4.9.10586.1106   1.273.781.0       0            7.0000                 0
# 3  4.18.1807.18075  1.275.1639.0       0            7.0000                 0
# 4  4.18.1807.18075   1.275.511.0       0            7.0000                 0
#
#    DefaultBrowsersIdentifier  ...  FirmwareManufacturerId_556.0  \
# 0                        NaN  ...                         False
# 1                        NaN  ...                         False
# 2                        NaN  ...                         False
# 3                        NaN  ...                         False
# 4                        NaN  ...                         False
#
#    FirmwareManufacturerId_628.0  FirmwareManufacturerOtros  OtrosRegionId  \
# 0                         False                      False          False
# 1                         False                       True          False
# 2                         False                      False          False
# 3                         False                      False          False
# 4                         False                      False           True
#
#    RegionId_1.0  RegionId_10.0  RegionId_11.0  RegionId_15.0  RegionId_3.0  \
# 0         False          False           True          False         False
# 1         False          False          False          False          True
# 2         False          False          False           True         False
# 3         False          False          False           True         False
# 4         False          False          False          False         False
#
#    RegionId_7.0
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 111 columns]

# %% [markdown]
# Aqui se podria hcer el mismo procedimiento que hemos hecho con `Census_FirmwareManufacturerIdentifier` o se borra directamente. Para hablarlo.

# %%
df[['OtrosRegionId','RegionId_1.0','RegionId_10.0','RegionId_11.0','RegionId_15.0','RegionId_3.0','RegionId_7.0']].corrwith(df['HasDetections'])
# Out:
# OtrosRegionId   -0.0142
# RegionId_1.0     0.0287
# RegionId_10.0    0.0113
# RegionId_11.0    0.0018
# RegionId_15.0   -0.0233
# RegionId_3.0    -0.0072
# RegionId_7.0     0.0012
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477655 entries, 0 to 499999
# Columns: 111 entries, Unnamed: 0 to RegionId_7.0
# dtypes: bool(38), float64(33), int64(17), object(23)
# memory usage: 287.0+ MB

# %% [markdown]
# ## Borramos las columnas que no necesitamos

# %%
df.drop(del_columns, axis=1, inplace=True)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#          ProductName  AVProductStatesIdentifier  AVProductsInstalled  \
# 0       win8defender                 53447.0000               1.0000
# 1       win8defender                 53447.0000               1.0000
# 2       win8defender                 46781.0000               2.0000
# 3       win8defender                 53447.0000               1.0000
# 4       win8defender                 47238.0000               2.0000
# ...              ...                        ...                  ...
# 443059  win8defender                 53447.0000               1.0000
# 443060  win8defender                 53447.0000               1.0000
# 443061  win8defender                 53447.0000               1.0000
# 443062  win8defender                 43856.0000               2.0000
# 443063  win8defender                 53447.0000               1.0000
#
#         AVProductsEnabled  Processor OsVer  OsSuite SkuEdition  IsProtected  \
# 0                  1.0000          0    10      256        Pro       1.0000
# 1                  1.0000          0    10      256        Pro       1.0000
# 2                  1.0000          0    10      768       Home       1.0000
# 3                  1.0000          0    10      768       Home       1.0000
# 4                  1.0000          0    10      256        Pro       1.0000
# ...                   ...        ...   ...      ...        ...          ...
# 443059             1.0000          0    10      768       Home       1.0000
# 443060             1.0000          0    10      768       Home       1.0000
# 443061             1.0000          1    10      256        Pro       1.0000
# 443062             1.0000          0    10      256        Pro       1.0000
# 443063             1.0000          0    10      256        Pro       1.0000
#
#         IeVerIdentifier  ...  FirmwareManufacturerId_556.0  \
# 0              137.0000  ...                         False
# 1              137.0000  ...                         False
# 2               74.0000  ...                         False
# 3              137.0000  ...                         False
# 4              137.0000  ...                         False
# ...                 ...  ...                           ...
# 443059          74.0000  ...                         False
# 443060         111.0000  ...                         False
# 443061         137.0000  ...                         False
# 443062         117.0000  ...                         False
# 443063         137.0000  ...                         False
#
#         FirmwareManufacturerId_628.0  FirmwareManufacturerOtros  \
# 0                              False                      False
# 1                              False                       True
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
# ...                              ...                        ...
# 443059                         False                       True
# 443060                         False                       True
# 443061                         False                      False
# 443062                          True                      False
# 443063                         False                      False
#
#         OtrosRegionId  RegionId_1.0  RegionId_10.0  RegionId_11.0  \
# 0               False         False          False           True
# 1               False         False          False          False
# 2               False         False          False          False
# 3               False         False          False          False
# 4                True         False          False          False
# ...               ...           ...            ...            ...
# 443059          False         False          False          False
# 443060          False         False          False          False
# 443061           True         False          False          False
# 443062          False          True          False          False
# 443063           True         False          False          False
#
#         RegionId_15.0 RegionId_3.0 RegionId_7.0
# 0               False        False        False
# 1               False         True        False
# 2                True        False        False
# 3                True        False        False
# 4               False        False        False
# ...               ...          ...          ...
# 443059           True        False        False
# 443060           True        False        False
# 443061          False        False        False
# 443062          False        False        False
# 443063          False        False        False
#
# [443064 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443064 entries, 0 to 443063
# Data columns (total 64 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   ProductName                               443064 non-null  object
#  1   AVProductStatesIdentifier                 443064 non-null  float64
#  2   AVProductsInstalled                       443064 non-null  float64
#  3   AVProductsEnabled                         443064 non-null  float64
#  4   Processor                                 443064 non-null  int64
#  5   OsVer                                     443064 non-null  object
#  6   OsSuite                                   443064 non-null  int64
#  7   SkuEdition                                443064 non-null  object
#  8   IsProtected                               443064 non-null  float64
#  9   IeVerIdentifier                           443064 non-null  float64
#  10  Firewall                                  443064 non-null  float64
#  11  UacLuaenable                              443064 non-null  float64
#  12  Census_OEMNameIdentifier                  443064 non-null  float64
#  13  Census_ProcessorCoreCount                 443064 non-null  float64
#  14  Census_ProcessorManufacturerIdentifier    443064 non-null  float64
#  15  Census_ProcessorModelIdentifier           443064 non-null  float64
#  16  Census_HasOpticalDiskDrive                443064 non-null  int64
#  17  Census_OSBuildNumber                      443064 non-null  int64
#  18  Census_OSWUAutoUpdateOptionsName          443064 non-null  object
#  19  Census_GenuineStateName                   443064 non-null  object
#  20  Census_ActivationChannel                  443064 non-null  object
#  21  HasDetections                             443064 non-null  int64
#  22  EngineVersion_trimmed                     443064 non-null  object
#  23  AppVersion_trimmed                        443064 non-null  object
#  24  AvSigVersion_trimmed                      443064 non-null  object
#  25  Platform_windows10                        443064 non-null  bool
#  26  Platform_windows7                         443064 non-null  bool
#  27  Platform_windows8                         443064 non-null  bool
#  28  Census_PrimaryDiskTypeName_HDD            443064 non-null  bool
#  29  Census_PrimaryDiskTypeName_Indefinido     443064 non-null  bool
#  30  Census_PrimaryDiskTypeName_SSD            443064 non-null  bool
#  31  Census_TotalPhysicalRAM_GB                443064 non-null  float64
#  32  Census_PowerPlatformRoleName_AppliancePC  443064 non-null  bool
#  33  Census_PowerPlatformRoleName_Desktop      443064 non-null  bool
#  34  Census_PowerPlatformRoleName_Mobile       443064 non-null  bool
#  35  Census_PowerPlatformRoleName_Server       443064 non-null  bool
#  36  Census_PowerPlatformRoleName_Slate        443064 non-null  bool
#  37  Census_PowerPlatformRoleName_Workstation  443064 non-null  bool
#  38  CALC_Census_OSBranch_rs                   443064 non-null  bool
#  39  CALC_Census_OSBranch_rs1                  443064 non-null  bool
#  40  CALC_Census_OSBranch_rs2                  443064 non-null  bool
#  41  CALC_Census_OSBranch_rs3                  443064 non-null  bool
#  42  CALC_Census_OSBranch_rs4                  443064 non-null  bool
#  43  CALC_Census_OSBranch_rs5                  443064 non-null  bool
#  44  CALC_Census_OSBranch_th1                  443064 non-null  bool
#  45  CALC_Census_OSBranch_th2                  443064 non-null  bool
#  46  Census_OSEdition_Core                     443064 non-null  bool
#  47  Census_OSEdition_CoreSingleLanguage       443064 non-null  bool
#  48  Census_OSEdition_Otro                     443064 non-null  bool
#  49  Census_OSEdition_Professional             443064 non-null  bool
#  50  FirmwareManufacturerId_142.0              443064 non-null  bool
#  51  FirmwareManufacturerId_355.0              443064 non-null  bool
#  52  FirmwareManufacturerId_500.0              443064 non-null  bool
#  53  FirmwareManufacturerId_554.0              443064 non-null  bool
#  54  FirmwareManufacturerId_556.0              443064 non-null  bool
#  55  FirmwareManufacturerId_628.0              443064 non-null  bool
#  56  FirmwareManufacturerOtros                 443064 non-null  bool
#  57  OtrosRegionId                             443064 non-null  bool
#  58  RegionId_1.0                              443064 non-null  bool
#  59  RegionId_10.0                             443064 non-null  bool
#  60  RegionId_11.0                             443064 non-null  bool
#  61  RegionId_15.0                             443064 non-null  bool
#  62  RegionId_3.0                              443064 non-null  bool
#  63  RegionId_7.0                              443064 non-null  bool
# dtypes: bool(38), float64(12), int64(5), object(9)
# memory usage: 103.9+ MB

# %% [markdown]
# ## Modificamos algunas columnas

# %%
df['OsSuite'] = df['OsSuite'].apply(lambda x: 1 if x==768 else 0)
df['SkuEdition'] = df['SkuEdition'].apply(lambda x: "Other" if x not in list(["Home", "Pro"]) else x)
df['IeVerIdentifier'] = df['IeVerIdentifier'].apply(lambda x: "Other" if x not in list([137.0000, 117.0000, 108.0000, 111.0000]) else x)
df['Census_OEMNameIdentifier'] = df['Census_OEMNameIdentifier'].apply(lambda x: "Other" if x not in list([2668.0000, 2102.0000, 1443.0000, 2206.0000, 585.0000, 525.0000]) else x)
df['Census_ProcessorCoreCount'] = df['Census_ProcessorCoreCount'].apply(lambda x: "Other" if x not in list([4.0, 2.0, 8.0]) else x)
df['Census_ActivationChannel'] = df['Census_ActivationChannel'].apply(lambda x: x.split(":")[0])

# %% [markdown]
# ## Census_ProcessorModelIdentifier normalizamos

# %% [markdown]
# ## Census_OSBuildNumber normalizamos

# %%
df.hist(bins=30, figsize=(15, 40), layout=(19, 3), edgecolor='black', color='skyblue')
plt.suptitle("Distribuciones de las Variables", fontsize=11)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='HasDetections', palette=['skyblue', 'salmon'], edgecolor='black')

plt.title("Distribución de la Variable Target", fontsize=14)
plt.xlabel("HasDetections (0 = No infectado, 1 = Infectado)", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)
plt.show()
# Out:
# /var/folders/gh/fgx2sy391b39mq0zmg0q_byr0000gn/T/ipykernel_41132/2538932364.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='HasDetections', palette=['skyblue', 'salmon'], edgecolor='black')
